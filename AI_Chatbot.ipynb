# %%
import requests
import os

# Set up GitHub credentials
GITHUB_TOKEN = "github_token"  # Replace with your actual token
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

# Function to get repository contents
def get_repo_contents(owner, repo, path=""):
    url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}?per_page=10"
    session = requests.Session()
    session.headers.update({"Authorization": f"token {GITHUB_TOKEN}"})
    response = session.get(url)

    #response = requests.get(url, headers=HEADERS, timeout=30)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.json()}")
        return []

# Function to download files from a repo
def download_repo_code(owner, repo, path="", save_dir="github_code"):
    os.makedirs(save_dir, exist_ok=True)  # Create the main directory if it doesn't exist
    contents = get_repo_contents(owner, repo, path)

    for file in contents:
        if file["type"] == "file" and file["name"].endswith((".py", ".js", ".java", ".md", ".txt")):
            # Download the file
            file_content = requests.get(file["download_url"]).text
            file_path = os.path.join(save_dir, file["name"])

            with open(file_path, "w", encoding="utf-8") as f:
                f.write(file_content)
            print(f"Downloaded: {file['name']}")

        elif file["type"] == "dir":
            new_dir = os.path.join(save_dir, file["name"])
            os.makedirs(new_dir, exist_ok=True)
            print(f"📂 Entering directory: {file['name']}")
            download_repo_code(owner, repo, file["path"], new_dir)  # Recursively fetch subdirectories

# Example usage (Start with a small repo)
download_repo_code("haoel", "leetcode")  # Replace with any repo of interest
# Out:
# Downloaded: README.md
# 📂 Entering directory: algorithms
# 📂 Entering directory: cpp
# 📂 Entering directory: 3Sum
# 📂 Entering directory: 3SumClosest
# 📂 Entering directory: 4Sum
# 📂 Entering directory: FindValidMatrixGivenRowAndColumnSums
# 📂 Entering directory: LRUCache
# 📂 Entering directory: NumberOfWaysToSplitString
# 📂 Entering directory: UTF8Validation
# 📂 Entering directory: accountsMerge
# 📂 Entering directory: addAndSearchWord
# 📂 Entering directory: addBinary
# 📂 Entering directory: addDigits
# 📂 Entering directory: addStrings
# 📂 Entering directory: addToArrayFormOfInteger
# 📂 Entering directory: addTwoNumbers
# 📂 Entering directory: additiveNumber
# 📂 Entering directory: anagrams
# 📂 Entering directory: arithmeticSlices
# 📂 Entering directory: backspaceStringCompare
# 📂 Entering directory: balancedBinaryTree
# 📂 Entering directory: basicCalculator
# 📂 Entering directory: bestTimeToBuyAndSellStock
# 📂 Entering directory: binarySearchTreeIterator
# 📂 Entering directory: binaryTreeInorderTraversal
# 📂 Entering directory: binaryTreeLevelOrderTraversal
# 📂 Entering directory: binaryTreeMaximumPathSum
# 📂 Entering directory: binaryTreePaths
# 📂 Entering directory: binaryTreePostorderTraversal
# 📂 Entering directory: binaryTreePreorderTraversal
# 📂 Entering directory: binaryTreeRightSideView
# 📂 Entering directory: binaryTreeUpsideDown
# 📂 Entering directory: binaryTreeZigzagLevelOrderTraversal
# 📂 Entering directory: binaryWatch
# 📂 Entering directory: bitwiseANDOfNumbersRange
# 📂 Entering directory: brokenCalculator
# 📂 Entering directory: buddyStrings
# 📂 Entering directory: buildingBoxes
# 📂 Entering directory: bulbSwitcher
# 📂 Entering directory: bullsAndCows
# 📂 Entering directory: burstBalloons
# 📂 Entering directory: calculateMoneyInLeetcodeBank
# 📂 Entering directory: candy
# 📂 Entering directory: checkIfArrayIsSortedAndRotated
# 📂 Entering directory: checkIfBinaryStringHasAtMostOneSegmentOfOnes
# 📂 Entering directory: checkIfNumberIsASumOfPowersOfThree
# 📂 Entering directory: checkIfOneStringSwapCanMakeStringsEqual
# 📂 Entering directory: checkIfTheSentenceIsPangram
# 📂 Entering directory: checkIfWordEqualsSummationOfTwoWords
# 📂 Entering directory: climbStairs
# 📂 Entering directory: cloneGraph
# 📂 Entering directory: closestDessertCost
# 📂 Entering directory: closestRoom
# 📂 Entering directory: closestSubsequenceSum
# 📂 Entering directory: coinChange
# 📂 Entering directory: combinationSum
# 📂 Entering directory: combinationSumIV
# 📂 Entering directory: combinations
# 📂 Entering directory: compareStringsByFrequencyOfTheSmallestCharacter
# 📂 Entering directory: compareVersionNumbers
# 📂 Entering directory: constructBinaryTreeFromInorderAndPostorderTraversal
# 📂 Entering directory: constructBinaryTreeFromPreorderAndInorderTraversal
# 📂 Entering directory: constructTheLexicographicallyLargestValidSequence
# 📂 Entering directory: containerWithMostWater
# 📂 Entering directory: containsDuplicate
# 📂 Entering directory: convertANumberToHexadecimal
# 📂 Entering directory: convertSortedArrayToBinarySearchTree
# 📂 Entering directory: convertSortedListToBinarySearchTree
# 📂 Entering directory: copyListWithRandomPointer
# 📂 Entering directory: countAndSay
# 📂 Entering directory: countCompleteTreeNodes
# 📂 Entering directory: countGoodMeals
# 📂 Entering directory: countItemsMatchingARule
# 📂 Entering directory: countNicePairsInAnArray
# 📂 Entering directory: countNumberOfHomogenousSubstrings
# 📂 Entering directory: countNumbersWithUniqueDigits
# 📂 Entering directory: countOddNumbersInAnIntervalRange
# 📂 Entering directory: countOfRangeSum
# 📂 Entering directory: countOfSmallerNumbersAfterSelf
# 📂 Entering directory: countPairsOfNodes
# 📂 Entering directory: countPairsWithXorInARange
# 📂 Entering directory: countPrimes
# 📂 Entering directory: countingBits
# 📂 Entering directory: courseSchedule
# 📂 Entering directory: non-recursive
# 📂 Entering directory: cousinsInBinaryTree
# 📂 Entering directory: createMaximumNumber
# 📂 Entering directory: decodeString
# 📂 Entering directory: decodeWays
# 📂 Entering directory: decodeXORedPermutation
# 📂 Entering directory: deleteNodeInALinkedList
# 📂 Entering directory: designAuthenticationManager
# 📂 Entering directory: detectCapital
# 📂 Entering directory: determineColorOfAChessboardSquare
# 📂 Entering directory: diameterOfBinaryTree
# 📂 Entering directory: differentWaysToAddParentheses
# 📂 Entering directory: distinctSubsequences
# 📂 Entering directory: distributeCoinsInBinaryTree
# 📂 Entering directory: divideTwoInt
# 📂 Entering directory: dungeonGame
# 📂 Entering directory: editDistance
# 📂 Entering directory: eggDropWith2EggsAndNFloors
# 📂 Entering directory: eliminationGame
# 📂 Entering directory: equalSumArraysWithMinimumNumberOfOperations
# 📂 Entering directory: evaluateDivision
# 📂 Entering directory: evaluateReversePolishNotation
# 📂 Entering directory: evaluateTheBracketPairsOfAString
# 📂 Entering directory: excelSheetColumnNumber
# 📂 Entering directory: excelSheetColumnTitle
# 📂 Entering directory: expressionAddOperators
# 📂 Entering directory: factorialTrailingZeroes
# 📂 Entering directory: fibonacciNumber
# 📂 Entering directory: filterRestaurantsByVeganFriendlyPriceAndDistance
# 📂 Entering directory: findAllAnagramsInAString
# 📂 Entering directory: findCenterOfStarGraph
# 📂 Entering directory: findKthLargestXorCoordinateValue
# 📂 Entering directory: findMedianFromDataStream
# 📂 Entering directory: findMinimumInRotatedSortedArray
# 📂 Entering directory: findNearestPointThatHasTheSameXOrYCoordinate
# 📂 Entering directory: findPeakElement
# 📂 Entering directory: findTheDifference
# 📂 Entering directory: findTheDuplicateNumber
# 📂 Entering directory: findTheHighestAltitude
# 📂 Entering directory: findTheWinnerOfAnArrayGame
# 📂 Entering directory: findTheWinnerOfTheCircularGame
# 📂 Entering directory: findXorSumOfAllPairsBitwiseAnd
# 📂 Entering directory: findingMkAverage
# 📂 Entering directory: findingTheUsersActiveMinutes
# 📂 Entering directory: firstBadVersion
# 📂 Entering directory: firstMissingPositive
# 📂 Entering directory: firstUniqueCharacterInAString
# 📂 Entering directory: fizzBuzz
# 📂 Entering directory: flattenBinaryTreeToLinkedList
# 📂 Entering directory: flattenNestedListIterator
# 📂 Entering directory: formArrayByConcatenatingSubarraysOfAnotherArray
# 📂 Entering directory: fractionToRecurringDecimal
# 📂 Entering directory: frequencyOfTheMostFrequentElement
# 📂 Entering directory: friendCircles
# 📂 Entering directory: frogJump
# 📂 Entering directory: gameOfLife
# 📂 Entering directory: gasStation
# 📂 Entering directory: generateParentheses
# 📂 Entering directory: grayCode
# 📂 Entering directory: greatestCommonDivisorOfStrings
# 📂 Entering directory: h-Index
# 📂 Entering directory: happyNumber
# 📂 Entering directory: houseRobber
# 📂 Entering directory: implementQueueUsingStacks
# 📂 Entering directory: implementStackUsingQueues
# 📂 Entering directory: implementTriePrefixTree
# 📂 Entering directory: increasingTripletSubsequence
# 📂 Entering directory: incrementalMemoryLeak
# 📂 Entering directory: insertDeleteGetRandom
# 📂 Entering directory: insertInterval
# 📂 Entering directory: insertionSortList
# 📂 Entering directory: integerBreak
# 📂 Entering directory: integerReplacement
# 📂 Entering directory: integerToEnglishWords
# 📂 Entering directory: integerToRoman
# 📂 Entering directory: interleavingString
# 📂 Entering directory: intersectionOfTwoArrays
# 📂 Entering directory: intersectionOfTwoLinkedLists
# 📂 Entering directory: intervalListIntersectons
# 📂 Entering directory: invertBinaryTree
# 📂 Entering directory: isSubsequence
# 📂 Entering directory: islandPerimeter
# 📂 Entering directory: isomorphicStrings
# 📂 Entering directory: jewelsAndStones
# 📂 Entering directory: jumpGame
# 📂 Entering directory: kthLargestElementInAnArray
# 📂 Entering directory: kthSmallestElementInaBST
# 📂 Entering directory: largestColorValueInADirectedGraph
# 📂 Entering directory: largestMergeOfTwoStrings
# 📂 Entering directory: largestNumber
# 📂 Entering directory: largestNumberAfterMutatingSubstring
# 📂 Entering directory: largestPerimeterTriangle
# 📂 Entering directory: largestRectangleInHistogram
# 📂 Entering directory: largestSubmatrixWithRearrangements
# 📂 Entering directory: largestSubstringBetweenTwoEqualCharacters
# 📂 Entering directory: latestTimeByReplacingHiddenDigits
# 📂 Entering directory: lengthOfLastWord
# 📂 Entering directory: letterCombinationsOfAPhoneNumber
# 📂 Entering directory: lexicographicalNumbers
# 📂 Entering directory: lexicographicallySmallestStringAfterApplyingOperations
# 📂 Entering directory: linkedListCycle
# 📂 Entering directory: linkedListRandomNode
# 📂 Entering directory: longerContiguousSegmentsOfOnesThanZeros
# 📂 Entering directory: longestAbsoluteFilePath
# 📂 Entering directory: longestCommonPrefix
# 📂 Entering directory: longestConsecutiveSequence
# 📂 Entering directory: longestIncreasingPathInAMatrix
# 📂 Entering directory: longestIncreasingSubsequence
# 📂 Entering directory: longestNiceSubstring
# 📂 Entering directory: longestPalindrome
# 📂 Entering directory: longestPalindromicSubsequence
# 📂 Entering directory: longestPalindromicSubstring
# 📂 Entering directory: longestSubstringOfAllVowelsInOrder
# 📂 Entering directory: longestSubstringWithAtLeastKRepeatingCharacters
# 📂 Entering directory: longestSubstringWithAtMostTwoDistinctCharacters
# 📂 Entering directory: longestSubstringWithoutRepeatingCharacters
# 📂 Entering directory: longestTurbulentSubarray
# 📂 Entering directory: longestValidParentheses
# 📂 Entering directory: lowestCommonAncestorOfABinarySearchTree
# 📂 Entering directory: lowestCommonAncestorOfABinaryTree
# 📂 Entering directory: majorityElement
# 📂 Entering directory: makeTheXorOfAllSegmentsEqualToZero
# 📂 Entering directory: mapOfHighestPeak
# 📂 Entering directory: matrixCellsInDistanceOrder
# 📂 Entering directory: maxAreaOfIsland
# 📂 Entering directory: maxPointsOnALine
# 📂 Entering directory: maximalRectangle
# 📂 Entering directory: maximalSquare
# 📂 Entering directory: maximizeNumberOfNiceDivisors
# 📂 Entering directory: maximizePalindromeLengthFromSubsequences
# 📂 Entering directory: maximizeScoreAfterNOperations
# 📂 Entering directory: maximumAbsoluteSumOfAnySubarray
# 📂 Entering directory: maximumAscendingSubarraySum
# 📂 Entering directory: maximumAveragePassRatio
# 📂 Entering directory: maximumAverageSubarray
# 📂 Entering directory: maximumBuildingHeight
# 📂 Entering directory: maximumDepthOfBinaryTree
# 📂 Entering directory: maximumDistanceBetweenAPairOfValues
# 📂 Entering directory: maximumElementAfterDecreasingAndRearranging
# 📂 Entering directory: maximumErasureValue
# 📂 Entering directory: maximumGap
# 📂 Entering directory: maximumIceCreamBars
# 📂 Entering directory: maximumNumberOfBallsInABox
# 📂 Entering directory: maximumNumberOfConsecutiveValuesYouCanMake
# 📂 Entering directory: maximumNumberOfEventsThatCanBeAttended
# 📂 Entering directory: maximumNumberOfGroupsGettingFreshDonuts
# 📂 Entering directory: maximumNumberOfWordsYouCanType
# 📂 Entering directory: maximumPopulationYear
# 📂 Entering directory: maximumProductOfTwoElementsInAnArray
# 📂 Entering directory: maximumProductOfWordLengths
# 📂 Entering directory: maximumProductSubarray
# 📂 Entering directory: maximumScoreFromPerformingMultiplicationOperations
# 📂 Entering directory: maximumScoreFromRemovingStones
# 📂 Entering directory: maximumScoreFromRemovingSubstrings
# 📂 Entering directory: maximumScoreOfAGoodSubarray
# 📂 Entering directory: maximumSubArray
# 📂 Entering directory: maximumSubarrayMinProduct
# 📂 Entering directory: maximumUnitsOnATruck
# 📂 Entering directory: maximumValueAfterInsertion
# 📂 Entering directory: maximumValueAtAGivenIndexInABoundedArray
# 📂 Entering directory: maximumXorForEachQuery
# 📂 Entering directory: medianOfTwoSortedArrays
# 📂 Entering directory: mergeIntervals
# 📂 Entering directory: mergeKSortedLists
# 📂 Entering directory: mergeStringsAlternately
# 📂 Entering directory: mergeTwoSortedArray
# 📂 Entering directory: mergeTwoSortedList
# 📂 Entering directory: minCostClimbingStairs
# 📂 Entering directory: minStack
# 📂 Entering directory: miniParser
# 📂 Entering directory: minimizeMaximumPairSumInArray
# 📂 Entering directory: minimumASCIIDeleteSumForTwoStrings
# 📂 Entering directory: minimumAbsoluteSumDifference
# 📂 Entering directory: minimumAdjacentSwapsToReachTheKthSmallestNumber
# 📂 Entering directory: minimumChangesToMakeAlternatingBinaryString
# 📂 Entering directory: minimumCostForTickets
# 📂 Entering directory: minimumDegreeOfAConnectedTrioInAGraph
# 📂 Entering directory: minimumDepthOfBinaryTree
# 📂 Entering directory: minimumDistanceToTheTargetElement
# 📂 Entering directory: minimumElementsToAddToFormAGivenSum
# 📂 Entering directory: minimumFallingPathSum
# 📂 Entering directory: minimumHeightTrees
# 📂 Entering directory: minimumInsertionsToBalanceAParenthesesString
# 📂 Entering directory: minimumIntervalToIncludeEachQuery
# 📂 Entering directory: minimumLengthOfStringAfterDeletingSimilarEnds
# 📂 Entering directory: minimumLimitOfBallsInABag
# 📂 Entering directory: minimumNumberOfOperationsToMoveAllBallsToEachBox
# 📂 Entering directory: minimumNumberOfOperationsToReinitializeAPermutation
# 📂 Entering directory: minimumNumberOfPeopleToTeach
# 📂 Entering directory: minimumOperationsToMakeArrayEqual
# 📂 Entering directory: minimumOperationsToMakeTheArrayIncreasing
# 📂 Entering directory: minimumPathSum
# 📂 Entering directory: minimumSidewayJumps
# 📂 Entering directory: minimumSizeSubarraySum
# 📂 Entering directory: minimumSpeedToArriveOnTime
# 📂 Entering directory: minimumWindowSubstring
# 📂 Entering directory: mirrorReflection
# 📂 Entering directory: missingNumber
# 📂 Entering directory: missingRanges
# 📂 Entering directory: mostCommonWord
# 📂 Entering directory: moveZeroes
# 📂 Entering directory: multiplyStrings
# 📂 Entering directory: nQueens
# 📂 Entering directory: nRepeatedElementInSize2NArray
# 📂 Entering directory: nextPermutation
# 📂 Entering directory: nimGame
# 📂 Entering directory: nthDigit
# 📂 Entering directory: numberOf1Bits
# 📂 Entering directory: numberOfDifferentIntegersInAString
# 📂 Entering directory: numberOfDifferentSubsequencesGcds
# 📂 Entering directory: numberOfDigitOne
# 📂 Entering directory: numberOfGoodWaysToSplitAString
# 📂 Entering directory: numberOfIslands
# 📂 Entering directory: numberOfOrdersInTheBacklog
# 📂 Entering directory: numberOfRecentCalls
# 📂 Entering directory: numberOfRectanglesThatCanFormTheLargestSquare
# 📂 Entering directory: numberOfRestrictedPathsFromFirstToLastNode
# 📂 Entering directory: numberOfStudentsUnableToEatLunch
# 📂 Entering directory: numberOfSubArraysWithOddSum
# 📂 Entering directory: numberOfSubstringsWithOnly1s
# 📂 Entering directory: oddEvenLinkedList
# 📂 Entering directory: oneEditDistance
# 📂 Entering directory: palindromeLinkedList
# 📂 Entering directory: palindromeNumber
# 📂 Entering directory: palindromePairs
# 📂 Entering directory: palindromePartitioning
# 📂 Entering directory: palindromicSubstrings
# 📂 Entering directory: partitionEqualSubsetSum
# 📂 Entering directory: partitionList
# 📂 Entering directory: pascalTriangle
# 📂 Entering directory: patchingArray
# 📂 Entering directory: pathSum
# 📂 Entering directory: peakIndexInAMountainArray
# 📂 Entering directory: peekingIterator
# 📂 Entering directory: perfectRectangle
# 📂 Entering directory: perfectSquares
# 📂 Entering directory: permutationSequence
# 📂 Entering directory: permutations
# 📂 Entering directory: plusOne
# 📂 Entering directory: populatingNextRightPointersInEachNode
# 📂 Entering directory: pow
# 📂 Entering directory: powerOfFour
# 📂 Entering directory: powerOfThree
# 📂 Entering directory: powerOfTwo
# 📂 Entering directory: processTasksUsingServers
# 📂 Entering directory: productOfArrayExceptSelf
# 📂 Entering directory: queriesOnNumberOfPointsInsideACircle
# 📂 Entering directory: queueReconstructionByHeight
# 📂 Entering directory: randomPickIndex
# 📂 Entering directory: randomPointInNonOverlappingRectangles
# 📂 Entering directory: rangeSumQuery-Immutable
# 📂 Entering directory: rangeSumQuery-Mutable
# 📂 Entering directory: rangeSumQuery2D-Immutable
# 📂 Entering directory: ransomNote
# 📂 Entering directory: readNCharactersGivenRead4
# 📂 Entering directory: reconstructItinerary
# 📂 Entering directory: recoverATreeFromPreorderTraversal
# 📂 Entering directory: recoverBinarySearchTree
# 📂 Entering directory: rectangleArea
# 📂 Entering directory: reformatPhoneNumber
# 📂 Entering directory: regularExpressionMatching
# 📂 Entering directory: removeDuplicateLetters
# 📂 Entering directory: removeDuplicatesFromSortedArray
# 📂 Entering directory: removeDuplicatesFromSortedList
# 📂 Entering directory: removeElement
# 📂 Entering directory: removeInvalidParentheses
# 📂 Entering directory: removeKDigits
# 📂 Entering directory: removeLinkedListElements
# 📂 Entering directory: removeNthNodeFromEndOfList
# 📂 Entering directory: reorderList
# 📂 Entering directory: repeatedDNASequences
# 📂 Entering directory: replaceAllDigitsWithCharacters
# 📂 Entering directory: restoreIPAddresses
# 📂 Entering directory: restoreTheArrayFromAdjacentPairs
# 📂 Entering directory: reverseBits
# 📂 Entering directory: reverseInteger
# 📂 Entering directory: reverseLinkedList
# 📂 Entering directory: reverseNodesInKGroup
# 📂 Entering directory: reverseString
# 📂 Entering directory: reverseVowelsOfAString
# 📂 Entering directory: reverseWordsInAString
# 📂 Entering directory: romanToInteger
# 📂 Entering directory: rotateArray
# 📂 Entering directory: rotateFunction
# 📂 Entering directory: rotateImage
# 📂 Entering directory: rotateList
# 📂 Entering directory: rotatingTheBox
# 📂 Entering directory: sameTree
# 📂 Entering directory: satisfiabilityOfEqualityEquations
# 📂 Entering directory: scrambleString
# 📂 Entering directory: search2DMatrix
# 📂 Entering directory: searchForRange
# 📂 Entering directory: searchInRotatedSortedArray
# 📂 Entering directory: searchInsertPosition
# 📂 Entering directory: seatReservationManager
# 📂 Entering directory: secondLargestDigitInAString
# 📂 Entering directory: sentenceScreenFitting
# 📂 Entering directory: sentenceSimilarity
# 📂 Entering directory: serializeAndDeserializeBinaryTree
# 📂 Entering directory: setMatrixZeroes
# 📂 Entering directory: shortEncodingOfWords
# 📂 Entering directory: shortestPalindrome
# 📂 Entering directory: shuffleAnArray
# 📂 Entering directory: shuffleString
# 📂 Entering directory: shuffleTheArray
# 📂 Entering directory: signOfTheProductOfAnArray
# 📂 Entering directory: simplifyPath
# 📂 Entering directory: singleNumber
# 📂 Entering directory: singleThreadedCpu
# 📂 Entering directory: slidingWindowMaximum
# 📂 Entering directory: smallestStringStartingFromLeaf
# 📂 Entering directory: sortArrayByParity
# 📂 Entering directory: sortColors
# 📂 Entering directory: sortList
# 📂 Entering directory: sortingTheSentence
# 📂 Entering directory: spiralMatrix
# 📂 Entering directory: splitArrayLargestSum
# 📂 Entering directory: splittingAStringIntoDescendingConsecutiveValues
# 📂 Entering directory: sqrt
# 📂 Entering directory: squaresOfASortedArray
# 📂 Entering directory: strStr
# 📂 Entering directory: stringToIntegerAtoi
# 📂 Entering directory: stringWithoutAAAOrBBB
# 📂 Entering directory: subsets
# 📂 Entering directory: substringWithConcatenationOfAllWords
# 📂 Entering directory: substringsOfSizeThreeWithDistinctCharacters
# 📂 Entering directory: sudokuSolver
# 📂 Entering directory: sumOfBeautyOfAllSubstrings
# 📂 Entering directory: sumOfDigitsInBaseK
# 📂 Entering directory: sumOfDigitsOfStringAfterConvert
# 📂 Entering directory: sumOfEvenNumbersAfterQueries
# 📂 Entering directory: sumOfFlooredPairs
# 📂 Entering directory: sumOfLeftLeaves
# 📂 Entering directory: sumOfTwoIntegers
# 📂 Entering directory: sumOfUniqueElements
# 📂 Entering directory: sumRootToLeafNumber
# 📂 Entering directory: summaryRanges
# 📂 Entering directory: superUglyNumber
# 📂 Entering directory: surroundedRegions
# 📂 Entering directory: swapNodesInPairs
# 📂 Entering directory: symmetricTree
# 📂 Entering directory: targetSum
# 📂 Entering directory: textJustification
# 📂 Entering directory: theSkylineProblem
# 📂 Entering directory: thirdMaximumNumber
# 📂 Entering directory: thousandSeparator
# 📂 Entering directory: threeConsecutiveOdds
# 📂 Entering directory: timeBasedKeyValueStore
# 📂 Entering directory: timeNeededToInformAllEmployees
# 📂 Entering directory: topKFrequentElements
# 📂 Entering directory: totalHammingDistance
# 📂 Entering directory: trappingRainWater
# 📂 Entering directory: treeOfCoprimes
# 📂 Entering directory: triangle
# 📂 Entering directory: triplesWithBitwiseANDEqualToZero
# 📂 Entering directory: truncateSentence
# 📂 Entering directory: tupleWithSameProduct
# 📂 Entering directory: twoArraysEqualByReversingSubArrays
# 📂 Entering directory: twoCityScheduling
# 📂 Entering directory: twoSum
# 📂 Entering directory: uglyNumber
# 📂 Entering directory: uniqueBinarySearchTrees
# 📂 Entering directory: uniqueEmailAddresses
# 📂 Entering directory: uniqueMorseCodeWords
# 📂 Entering directory: uniqueNumberOfOccurrences
# 📂 Entering directory: uniquePaths
# 📂 Entering directory: validNumber
# 📂 Entering directory: validPalindrome
# 📂 Entering directory: validParentheses
# 📂 Entering directory: validPerfectSquare
# 📂 Entering directory: validSudoku
# 📂 Entering directory: validateBinarySearchTree
# 📂 Entering directory: verifyPreorderSerializationOfABinaryTree
# 📂 Entering directory: verticalOrderTraversalOfABinaryTree
# 📂 Entering directory: videoStitching
# 📂 Entering directory: waysToSplitArrayIntoThreeSubarrays
# 📂 Entering directory: wiggleSort
# 📂 Entering directory: wiggleSubsequence
# 📂 Entering directory: wildcardMatching
# 📂 Entering directory: wordBreak
# 📂 Entering directory: wordLadder
# 📂 Entering directory: wordPattern
# 📂 Entering directory: wordSearch
# 📂 Entering directory: zigZagConversion
# 📂 Entering directory: golang
# 📂 Entering directory: twoSum
# 📂 Entering directory: java
# 📂 Entering directory: src
# 📂 Entering directory: LargestNumberAfterMutatingSubstring
# Downloaded: largestNumberAfterMutatingSubstring.java
# 📂 Entering directory: MaxSubArray
# Downloaded: MaxSubarray.java
# 📂 Entering directory: RotateImage
# Downloaded: rotateImage.java
# 📂 Entering directory: balancedBinaryTree
# Downloaded: TreeNode.java
# Downloaded: balancedBinaryTree.java
# Downloaded: balancedBinaryTreeTest.java
# 📂 Entering directory: binarySearchTreeIterator
# Downloaded: TreeNode.java
# Downloaded: binarySearchTreeIterator.java
# Downloaded: binarySearchTreeIteratorTest.java
# 📂 Entering directory: binaryTreeBFSTraversal
# Downloaded: TreeNode.java
# Downloaded: binaryTreeBFSTraversal.java
# Downloaded: binaryTreeBFSTraversalTest.java
# 📂 Entering directory: binaryTreeLevelOrderTraversal
# Downloaded: TreeNode.java
# Downloaded: binaryTreeLevelOrderTraversal.java
# Downloaded: binaryTreeLevelOrderTraversalTest.java
# 📂 Entering directory: binaryTreeMaximumPathSum
# Downloaded: TreeNode.java
# Downloaded: binaryTreeMaximumPathSum.java
# Downloaded: binaryTreeMaximumPathSumTest.java
# 📂 Entering directory: binaryTreePreorderTraversal
# Downloaded: TreeNode.java
# Downloaded: binaryTreePreorderTraversal.java
# Downloaded: binaryTreePreorderTraversalTest.java
# Downloaded: containerwithmostwater.java
# 📂 Entering directory: countAndSay
# Downloaded: CountAndSay.java
# Downloaded: TestCountAndSay.java
# 📂 Entering directory: dynamicProgramming
# 📂 Entering directory: climbStairs
# Downloaded: climbStairs.java
# Downloaded: climbStairsTest.java
# 📂 Entering directory: minimumPathSum
# Downloaded: minimumPathSum.java
# Downloaded: minimumPathSumTest.java
# 📂 Entering directory: triangle
# Downloaded: triangle.java
# Downloaded: triangleTest.java
# 📂 Entering directory: uniquePaths
# Downloaded: uniquePaths.java
# Downloaded: uniquePathsII.java
# Downloaded: uniquePathsIITest.java
# Downloaded: uniquePathsTest.java
# 📂 Entering directory: findMinimumInRotatedSortedArray
# Downloaded: findMinimumInRotatedSortedArray.java
# Downloaded: findMinimumInRotatedSortedArrayTest.java
# 📂 Entering directory: findPeakElement
# Downloaded: findPeakElement.java
# Downloaded: findPeakElementTest.java
# 📂 Entering directory: firstBadVersion
# Downloaded: VersionControl.java
# Downloaded: firstBadVersion.java
# Downloaded: firstBadVersionTest.java
# 📂 Entering directory: inorderSuccessorInBST
# Downloaded: TreeNode.java
# Downloaded: inorderSuccessorInBST.java
# Downloaded: inorderSuccessorInBSTTest.java
# 📂 Entering directory: lengthOfLastWord
# Downloaded: LengthOfLastWord.java
# Downloaded: TestLengthOfLastWord.java
# 📂 Entering directory: lowestCommonAncestorOfABinaryTree
# Downloaded: TreeNode.java
# Downloaded: lowestCommonAncestorOfABinaryTree.java
# Downloaded: lowestCommonAncestorOfABinaryTreeTest.java
# 📂 Entering directory: lruCache
# Downloaded: LRUCache.java
# Downloaded: LRUCacheTest.java
# 📂 Entering directory: maximumDepthOfBinaryTree
# Downloaded: TreeNode.java
# Downloaded: maximumDepthOfBinaryTree.java
# Downloaded: maximumDepthOfBinaryTreeTest.java
# 📂 Entering directory: minStack
# Downloaded: MinStack.java
# Downloaded: TestMinStack.java
# 📂 Entering directory: myQueue
# Downloaded: MyQueue.java
# Downloaded: TestMyQueue.java
# 📂 Entering directory: myStack
# Downloaded: MyStack.java
# Downloaded: TestMyStack.java
# 📂 Entering directory: palindromeNumber
# Downloaded: PalindromeNumber.java
# Downloaded: TestPalindromeNumber.java
# 📂 Entering directory: powXn
# Downloaded: PowXn.java
# Downloaded: TestPowXn.java
# 📂 Entering directory: removeDuplicatesFromSortedArray
# Downloaded: RemoveDuplicatesFromSortedArray.java
# Downloaded: TestRemoveDuplicates.java
# 📂 Entering directory: reverseLinkedList
# Downloaded: ListNode.java
# Downloaded: ReverseLinkedList.java
# Downloaded: TestReverseLinkedList.java
# 📂 Entering directory: reverseLinkedListII
# Downloaded: ListNode.java
# Downloaded: ReverseLinkedListII.java
# Downloaded: TestReverseLinkedListII.java
# 📂 Entering directory: reverseWordsInAString
# Downloaded: ReverseWordsInAString.java
# Downloaded: TestReverseWordsInAString.java
# 📂 Entering directory: rotateArray
# Downloaded: RotateArray.java
# Downloaded: TestRotateArray.java
# 📂 Entering directory: search2DMatrix
# Downloaded: search2DMatrix.java
# Downloaded: search2DMatrixTest.java
# 📂 Entering directory: searchA2DMatrixII
# Downloaded: SearchA2DMatrixII.java
# Downloaded: Test_240.java
# 📂 Entering directory: searchForRange
# Downloaded: searchForRange.java
# Downloaded: searchForRangeTest.java
# 📂 Entering directory: searchInABigSortedArray
# Downloaded: searchInABigSortedArray.java
# Downloaded: searchInABigSortedArrayTest.java
# 📂 Entering directory: searchInRotatedSortedArray
# Downloaded: searchInRotatedSortedArray.java
# Downloaded: searchInRotatedSortedArrayTest.java
# 📂 Entering directory: searchInsertPosition
# Downloaded: searchInsertPosition.java
# Downloaded: searchInsertPositionTest.java
# 📂 Entering directory: searchRangeInBinarySearchTree
# Downloaded: TreeNode.java
# Downloaded: searchRangeInBinarySearchTree.java
# Downloaded: searchRangeInBinarySearchTreeTest.java
# 📂 Entering directory: strStr
# Downloaded: StrStrKmp.java
# Downloaded: TestStrStrKmp.java
# Downloaded: strStr.java
# Downloaded: strStrTest.java
# 📂 Entering directory: subsets
# Downloaded: subsets.java
# Downloaded: subsetsII.java
# Downloaded: subsetsIITest.java
# Downloaded: subsetsTest.java
# 📂 Entering directory: validAnagram
# Downloaded: TestValidAnagram.java
# Downloaded: ValidAnagram.java
# 📂 Entering directory: validPalindrome
# Downloaded: TestValidPalindrome.java
# Downloaded: ValidPalindrome.java
# 📂 Entering directory: validateBinarySearchTree
# Downloaded: TreeNode.java
# Downloaded: validateBinarySearchTree.java
# Downloaded: validateBinarySearchTreeTest.java
# 📂 Entering directory: python
# 📂 Entering directory: 1-bitAnd2-bitCharacters
# Downloaded: isOneBitCharacter.py
# 📂 Entering directory: AddOneRowToTree
# Downloaded: addOneRow.py
# 📂 Entering directory: BinarySearchTreeIterator
# Downloaded: BSTIterator.py
# 📂 Entering directory: BinaryTreePostorderTraversal
# Downloaded: postorderTraversal.py
# 📂 Entering directory: BinaryTreeTilt
# Downloaded: findTilt.py
# 📂 Entering directory: BinaryTreeZigzagLevelOrderTraversal
# Downloaded: zigzagLevelOrder.py
# 📂 Entering directory: CheckCompletenessOfABinaryTree
# Downloaded: isCompleteTree.py
# 📂 Entering directory: ConstructBinaryTreeFromInorderAndPostorderTraversal
# Downloaded: buildTree.py
# 📂 Entering directory: ConstructBinaryTreeFromPreorderAndInorderTraversal
# Downloaded: buildTree.py
# 📂 Entering directory: ContainsDuplicateII
# Downloaded: containsNearbyDuplicate.py
# 📂 Entering directory: ContainsDuplicateIII
# Downloaded: containsNearbyAlmostDuplicate.py
# 📂 Entering directory: ConvertBSTtoGreaterTree
# Downloaded: convertBST.py
# 📂 Entering directory: CopyListWithRandomPointer
# Downloaded: copyRandomList.py
# 📂 Entering directory: CountCompleteTreeNodes
# Downloaded: countNodes.py
# 📂 Entering directory: DeleteNodeInABST
# Downloaded: deleteNode.py
# 📂 Entering directory: DiameterOfBinaryTree
# Downloaded: diameterOfBinaryTree.py
# 📂 Entering directory: DifferentWaysToAddParentheses
# Downloaded: diffWaysToCompute.py
# 📂 Entering directory: FibonacciNumber
# Downloaded: fib.py
# 📂 Entering directory: FindDuplicateSubtrees
# Downloaded: findDuplicateSubtrees.py
# 📂 Entering directory: FindTheDuplicateNumber
# Downloaded: findDuplicate.py
# 📂 Entering directory: FlattenBinaryTreeToLinkedList
# Downloaded: flatten.py
# 📂 Entering directory: FlipBinaryTreeToMatchPreorderTraversal
# Downloaded: flipMatchVoyage.py
# 📂 Entering directory: FlipEquivalentBinaryTrees
# Downloaded: flipEquiv.py
# 📂 Entering directory: HappyNumber
# Downloaded: isHappy.py
# 📂 Entering directory: HouseRobber
# Downloaded: rob.py
# 📂 Entering directory: HouseRobberIII
# Downloaded: rob.py
# 📂 Entering directory: ImageSmoother
# Downloaded: imageSmoother.py
# 📂 Entering directory: InsertionSortList
# Downloaded: insertionSortList.py
# 📂 Entering directory: K-diffPairsInAnArray
# Downloaded: findPairs.py
# 📂 Entering directory: KthSmallestElementInABST
# Downloaded: kthSmallest.py
# 📂 Entering directory: LargestNumberAtLeastTwiceOfOthers
# Downloaded: dominantIndex.py
# 📂 Entering directory: LargestPerimeterTriangle
# Downloaded: largestPerimeter.py
# 📂 Entering directory: LinkedListCycleII
# Downloaded: detectCycle.py
# 📂 Entering directory: LongestConsecutiveSequence
# Downloaded: LongestConsecutive.py
# 📂 Entering directory: LongestContinuousIncreasingSubsequence
# Downloaded: findLengthOfLCIS.py
# 📂 Entering directory: LongestTurbulentSubarray
# Downloaded: maxTurbulenceSize.py
# 📂 Entering directory: LongestUnivaluePath
# Downloaded: longestUnivaluePath.py
# 📂 Entering directory: LowestCommonAncestorOfABinarySearchTree
# Downloaded: lowestCommonAncestor.py
# 📂 Entering directory: LowestCommonAncestorOfABinaryTree
# Downloaded: lowestCommonAncestor.py
# 📂 Entering directory: MaximizeDistanceToClosestPerson
# Downloaded: maxDistToClosest.py
# 📂 Entering directory: MaximumAverageSubarrayI
# Downloaded: findMaxAverage.py
# 📂 Entering directory: MaximumProductOfThreeNumbers
# Downloaded: maximumProduct.py
# 📂 Entering directory: MaximumWidthOfBinaryTree
# Downloaded: widthOfBinaryTree.py
# 📂 Entering directory: MiddleOfTheLinkedList
# Downloaded: middleOfTheLinkedList.py
# 📂 Entering directory: MinCostClimbingStairs
# Downloaded: minCostClimbingStairs.py
# 📂 Entering directory: Non-decreasingArray
# Downloaded: checkPossibility.py
# 📂 Entering directory: NumberOfIslands
# Downloaded: numIslands.py
# 📂 Entering directory: PancakeSorting
# Downloaded: pancakeSort.py
# 📂 Entering directory: PartitionList
# Downloaded: partition.py
# 📂 Entering directory: PathSumII
# Downloaded: pathSum.py
# 📂 Entering directory: PathSumIII
# Downloaded: pathSum.py
# 📂 Entering directory: PopulatingNextRightPointersInEachNode
# Downloaded: connect.py
# 📂 Entering directory: PopulatingNextRightPointersInEachNodeII
# Downloaded: connect.py
# 📂 Entering directory: PositionsOfLargeGroups
# Downloaded: largeGroupPositions.py
# 📂 Entering directory: PrintBinaryTree
# Downloaded: printTree.py
# 📂 Entering directory: RedundantConnection
# Downloaded: findRedundantConnection.py
# 📂 Entering directory: RemoveDuplicatesFromSortedListII
# Downloaded: deleteDuplicates.py
# 📂 Entering directory: RemoveNthNodeFromEndOfList
# Downloaded: removeNthFromEnd.py
# 📂 Entering directory: ReorderList
# Downloaded: reorderList.py
# 📂 Entering directory: RevealCardsInIncreasingOrder
# Downloaded: deckRevealedIncreasing.py
# 📂 Entering directory: ReverseLinkedListII
# Downloaded: reverseBetween.py
# 📂 Entering directory: SearchA2DMatrixII
# Downloaded: searchMatrix.py
# 📂 Entering directory: SecondMinimumNodeInABinaryTree
# Downloaded: findSecondMinimumValue.py
# 📂 Entering directory: SerializeAndDeserializeBST
# Downloaded: serialize.py
# 📂 Entering directory: ShortestUnsortedContinuousSubarray
# Downloaded: findUnsortedSubarray.py
# 📂 Entering directory: SingleNumberII
# Downloaded: SingleNumberII.py
# 📂 Entering directory: SortList
# Downloaded: sortList.py
# 📂 Entering directory: SquaresOfSortedArray
# Downloaded: sortedSquares.py
# 📂 Entering directory: Subsets
# Downloaded: subsets.py
# 📂 Entering directory: SubtreeOfAnotherTree
# Downloaded: isSubtree.py
# 📂 Entering directory: SumOfLeftLeaves
# Downloaded: sumOfLeftLeaves.py
# 📂 Entering directory: SumRootToLeafNumbers
# Downloaded: sumNumbers.py
# 📂 Entering directory: SwimInRisingWater
# Downloaded: swim_in_rising_water.py
# 📂 Entering directory: ThirdMaximumNumber
# Downloaded: thirdMax.py
# 📂 Entering directory: UniqueBinarySearchTrees
# Downloaded: numTrees.py
# 📂 Entering directory: UniqueBinarySearchTreesII
# Downloaded: generateTrees.py
# 📂 Entering directory: ValidMountainArray
# Downloaded: validMountainArray.py
# 📂 Entering directory: ValidateBinarySearchTree
# Downloaded: isValidBST.py
# 📂 Entering directory: XOfAKindInADeckOfCards
# Downloaded: hasGroupsSizeX.py
# 📂 Entering directory: firstMissingPositive
# Downloaded: firstMissingPositive.py
# 📂 Entering directory: jumpGame
# Downloaded: jumpGame.py
# 📂 Entering directory: uniquePaths
# Downloaded: uniquePathsIII.py
# 📂 Entering directory: database
# Downloaded: README.md
# 📂 Entering directory: scripts
# Downloaded: README.md
# 📂 Entering directory: lib
# 📂 Entering directory: shell
# Downloaded: README.md

# %%
import torch
print("Is CUDA available? ", torch.cuda.is_available())
print("GPU Device: ", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found")
# Out:
# Is CUDA available?  True
# GPU Device:  Tesla T4

# %%
# !ls -R github_code
# Out:
# github_code:
# algorithms  database  README.md  scripts  shell
#
# github_code/algorithms:
# cpp  golang  java  python
#
# github_code/algorithms/cpp:
# 3Sum
# 3SumClosest
# 4Sum
# accountsMerge
# addAndSearchWord
# addBinary
# addDigits
# additiveNumber
# addStrings
# addToArrayFormOfInteger
# addTwoNumbers
# anagrams
# arithmeticSlices
# backspaceStringCompare
# balancedBinaryTree
# basicCalculator
# bestTimeToBuyAndSellStock
# binarySearchTreeIterator
# binaryTreeInorderTraversal
# binaryTreeLevelOrderTraversal
# binaryTreeMaximumPathSum
# binaryTreePaths
# binaryTreePostorderTraversal
# binaryTreePreorderTraversal
# binaryTreeRightSideView
# binaryTreeUpsideDown
# binaryTreeZigzagLevelOrderTraversal
# binaryWatch
# bitwiseANDOfNumbersRange
# brokenCalculator
# buddyStrings
# buildingBoxes
# bulbSwitcher
# bullsAndCows
# burstBalloons
# calculateMoneyInLeetcodeBank
# candy
# checkIfArrayIsSortedAndRotated
# checkIfBinaryStringHasAtMostOneSegmentOfOnes
# checkIfNumberIsASumOfPowersOfThree
# checkIfOneStringSwapCanMakeStringsEqual
# checkIfTheSentenceIsPangram
# checkIfWordEqualsSummationOfTwoWords
# climbStairs
# cloneGraph
# closestDessertCost
# closestRoom
# closestSubsequenceSum
# coinChange
# combinations
# combinationSum
# combinationSumIV
# compareStringsByFrequencyOfTheSmallestCharacter
# compareVersionNumbers
# constructBinaryTreeFromInorderAndPostorderTraversal
# constructBinaryTreeFromPreorderAndInorderTraversal
# constructTheLexicographicallyLargestValidSequence
# containerWithMostWater
# containsDuplicate
# convertANumberToHexadecimal
# convertSortedArrayToBinarySearchTree
# convertSortedListToBinarySearchTree
# copyListWithRandomPointer
# countAndSay
# countCompleteTreeNodes
# countGoodMeals
# countingBits
# countItemsMatchingARule
# countNicePairsInAnArray
# countNumberOfHomogenousSubstrings
# countNumbersWithUniqueDigits
# countOddNumbersInAnIntervalRange
# countOfRangeSum
# countOfSmallerNumbersAfterSelf
# countPairsOfNodes
# countPairsWithXorInARange
# countPrimes
# courseSchedule
# cousinsInBinaryTree
# createMaximumNumber
# decodeString
# decodeWays
# decodeXORedPermutation
# deleteNodeInALinkedList
# designAuthenticationManager
# detectCapital
# determineColorOfAChessboardSquare
# diameterOfBinaryTree
# differentWaysToAddParentheses
# distinctSubsequences
# distributeCoinsInBinaryTree
# divideTwoInt
# dungeonGame
# editDistance
# eggDropWith2EggsAndNFloors
# eliminationGame
# equalSumArraysWithMinimumNumberOfOperations
# evaluateDivision
# evaluateReversePolishNotation
# evaluateTheBracketPairsOfAString
# excelSheetColumnNumber
# excelSheetColumnTitle
# expressionAddOperators
# factorialTrailingZeroes
# fibonacciNumber
# filterRestaurantsByVeganFriendlyPriceAndDistance
# findAllAnagramsInAString
# findCenterOfStarGraph
# findingMkAverage
# findingTheUsersActiveMinutes
# findKthLargestXorCoordinateValue
# findMedianFromDataStream
# findMinimumInRotatedSortedArray
# findNearestPointThatHasTheSameXOrYCoordinate
# findPeakElement
# findTheDifference
# findTheDuplicateNumber
# findTheHighestAltitude
# findTheWinnerOfAnArrayGame
# findTheWinnerOfTheCircularGame
# FindValidMatrixGivenRowAndColumnSums
# findXorSumOfAllPairsBitwiseAnd
# firstBadVersion
# firstMissingPositive
# firstUniqueCharacterInAString
# fizzBuzz
# flattenBinaryTreeToLinkedList
# flattenNestedListIterator
# formArrayByConcatenatingSubarraysOfAnotherArray
# fractionToRecurringDecimal
# frequencyOfTheMostFrequentElement
# friendCircles
# frogJump
# gameOfLife
# gasStation
# generateParentheses
# grayCode
# greatestCommonDivisorOfStrings
# happyNumber
# h-Index
# houseRobber
# implementQueueUsingStacks
# implementStackUsingQueues
# implementTriePrefixTree
# increasingTripletSubsequence
# incrementalMemoryLeak
# insertDeleteGetRandom
# insertInterval
# insertionSortList
# integerBreak
# integerReplacement
# integerToEnglishWords
# integerToRoman
# interleavingString
# intersectionOfTwoArrays
# intersectionOfTwoLinkedLists
# intervalListIntersectons
# invertBinaryTree
# islandPerimeter
# isomorphicStrings
# isSubsequence
# jewelsAndStones
# jumpGame
# kthLargestElementInAnArray
# kthSmallestElementInaBST
# largestColorValueInADirectedGraph
# largestMergeOfTwoStrings
# largestNumber
# largestNumberAfterMutatingSubstring
# largestPerimeterTriangle
# largestRectangleInHistogram
# largestSubmatrixWithRearrangements
# largestSubstringBetweenTwoEqualCharacters
# latestTimeByReplacingHiddenDigits
# lengthOfLastWord
# letterCombinationsOfAPhoneNumber
# lexicographicallySmallestStringAfterApplyingOperations
# lexicographicalNumbers
# linkedListCycle
# linkedListRandomNode
# longerContiguousSegmentsOfOnesThanZeros
# longestAbsoluteFilePath
# longestCommonPrefix
# longestConsecutiveSequence
# longestIncreasingPathInAMatrix
# longestIncreasingSubsequence
# longestNiceSubstring
# longestPalindrome
# longestPalindromicSubsequence
# longestPalindromicSubstring
# longestSubstringOfAllVowelsInOrder
# longestSubstringWithAtLeastKRepeatingCharacters
# longestSubstringWithAtMostTwoDistinctCharacters
# longestSubstringWithoutRepeatingCharacters
# longestTurbulentSubarray
# longestValidParentheses
# lowestCommonAncestorOfABinarySearchTree
# lowestCommonAncestorOfABinaryTree
# LRUCache
# majorityElement
# makeTheXorOfAllSegmentsEqualToZero
# mapOfHighestPeak
# matrixCellsInDistanceOrder
# maxAreaOfIsland
# maximalRectangle
# maximalSquare
# maximizeNumberOfNiceDivisors
# maximizePalindromeLengthFromSubsequences
# maximizeScoreAfterNOperations
# maximumAbsoluteSumOfAnySubarray
# maximumAscendingSubarraySum
# maximumAveragePassRatio
# maximumAverageSubarray
# maximumBuildingHeight
# maximumDepthOfBinaryTree
# maximumDistanceBetweenAPairOfValues
# maximumElementAfterDecreasingAndRearranging
# maximumErasureValue
# maximumGap
# maximumIceCreamBars
# maximumNumberOfBallsInABox
# maximumNumberOfConsecutiveValuesYouCanMake
# maximumNumberOfEventsThatCanBeAttended
# maximumNumberOfGroupsGettingFreshDonuts
# maximumNumberOfWordsYouCanType
# maximumPopulationYear
# maximumProductOfTwoElementsInAnArray
# maximumProductOfWordLengths
# maximumProductSubarray
# maximumScoreFromPerformingMultiplicationOperations
# maximumScoreFromRemovingStones
# maximumScoreFromRemovingSubstrings
# maximumScoreOfAGoodSubarray
# maximumSubArray
# maximumSubarrayMinProduct
# maximumUnitsOnATruck
# maximumValueAfterInsertion
# maximumValueAtAGivenIndexInABoundedArray
# maximumXorForEachQuery
# maxPointsOnALine
# medianOfTwoSortedArrays
# mergeIntervals
# mergeKSortedLists
# mergeStringsAlternately
# mergeTwoSortedArray
# mergeTwoSortedList
# minCostClimbingStairs
# minimizeMaximumPairSumInArray
# minimumAbsoluteSumDifference
# minimumAdjacentSwapsToReachTheKthSmallestNumber
# minimumASCIIDeleteSumForTwoStrings
# minimumChangesToMakeAlternatingBinaryString
# minimumCostForTickets
# minimumDegreeOfAConnectedTrioInAGraph
# minimumDepthOfBinaryTree
# minimumDistanceToTheTargetElement
# minimumElementsToAddToFormAGivenSum
# minimumFallingPathSum
# minimumHeightTrees
# minimumInsertionsToBalanceAParenthesesString
# minimumIntervalToIncludeEachQuery
# minimumLengthOfStringAfterDeletingSimilarEnds
# minimumLimitOfBallsInABag
# minimumNumberOfOperationsToMoveAllBallsToEachBox
# minimumNumberOfOperationsToReinitializeAPermutation
# minimumNumberOfPeopleToTeach
# minimumOperationsToMakeArrayEqual
# minimumOperationsToMakeTheArrayIncreasing
# minimumPathSum
# minimumSidewayJumps
# minimumSizeSubarraySum
# minimumSpeedToArriveOnTime
# minimumWindowSubstring
# miniParser
# minStack
# mirrorReflection
# missingNumber
# missingRanges
# mostCommonWord
# moveZeroes
# multiplyStrings
# nextPermutation
# nimGame
# nQueens
# nRepeatedElementInSize2NArray
# nthDigit
# numberOf1Bits
# numberOfDifferentIntegersInAString
# numberOfDifferentSubsequencesGcds
# numberOfDigitOne
# numberOfGoodWaysToSplitAString
# numberOfIslands
# numberOfOrdersInTheBacklog
# numberOfRecentCalls
# numberOfRectanglesThatCanFormTheLargestSquare
# numberOfRestrictedPathsFromFirstToLastNode
# numberOfStudentsUnableToEatLunch
# numberOfSubArraysWithOddSum
# numberOfSubstringsWithOnly1s
# NumberOfWaysToSplitString
# oddEvenLinkedList
# oneEditDistance
# palindromeLinkedList
# palindromeNumber
# palindromePairs
# palindromePartitioning
# palindromicSubstrings
# partitionEqualSubsetSum
# partitionList
# pascalTriangle
# patchingArray
# pathSum
# peakIndexInAMountainArray
# peekingIterator
# perfectRectangle
# perfectSquares
# permutations
# permutationSequence
# plusOne
# populatingNextRightPointersInEachNode
# pow
# powerOfFour
# powerOfThree
# powerOfTwo
# processTasksUsingServers
# productOfArrayExceptSelf
# queriesOnNumberOfPointsInsideACircle
# queueReconstructionByHeight
# randomPickIndex
# randomPointInNonOverlappingRectangles
# rangeSumQuery2D-Immutable
# rangeSumQuery-Immutable
# ransomNote
# readNCharactersGivenRead4
# reconstructItinerary
# recoverATreeFromPreorderTraversal
# recoverBinarySearchTree
# rectangleArea
# reformatPhoneNumber
# regularExpressionMatching
# removeDuplicateLetters
# removeDuplicatesFromSortedArray
# removeDuplicatesFromSortedList
# removeElement
# removeInvalidParentheses
# removeKDigits
# removeLinkedListElements
# removeNthNodeFromEndOfList
# reorderList
# repeatedDNASequences
# replaceAllDigitsWithCharacters
# restoreIPAddresses
# restoreTheArrayFromAdjacentPairs
# reverseBits
# reverseInteger
# reverseLinkedList
# reverseNodesInKGroup
# reverseString
# reverseVowelsOfAString
# reverseWordsInAString
# romanToInteger
# rotateArray
# rotateFunction
# rotateImage
# rotateList
# rotatingTheBox
# sameTree
# satisfiabilityOfEqualityEquations
# scrambleString
# search2DMatrix
# searchForRange
# searchInRotatedSortedArray
# searchInsertPosition
# seatReservationManager
# secondLargestDigitInAString
# sentenceScreenFitting
# sentenceSimilarity
# serializeAndDeserializeBinaryTree
# setMatrixZeroes
# shortEncodingOfWords
# shortestPalindrome
# shuffleAnArray
# shuffleString
# shuffleTheArray
# signOfTheProductOfAnArray
# simplifyPath
# singleNumber
# singleThreadedCpu
# slidingWindowMaximum
# smallestStringStartingFromLeaf
# sortArrayByParity
# sortColors
# sortingTheSentence
# sortList
# spiralMatrix
# splitArrayLargestSum
# splittingAStringIntoDescendingConsecutiveValues
# sqrt
# squaresOfASortedArray
# stringToIntegerAtoi
# stringWithoutAAAOrBBB
# strStr
# subsets
# substringsOfSizeThreeWithDistinctCharacters
# substringWithConcatenationOfAllWords
# sudokuSolver
# summaryRanges
# sumOfBeautyOfAllSubstrings
# sumOfDigitsInBaseK
# sumOfDigitsOfStringAfterConvert
# sumOfEvenNumbersAfterQueries
# sumOfFlooredPairs
# sumOfLeftLeaves
# sumOfTwoIntegers
# sumOfUniqueElements
# sumRootToLeafNumber
# superUglyNumber
# surroundedRegions
# swapNodesInPairs
# symmetricTree
# targetSum
# textJustification
# theSkylineProblem
# thirdMaximumNumber
# thousandSeparator
# threeConsecutiveOdds
# timeBasedKeyValueStore
# timeNeededToInformAllEmployees
# topKFrequentElements
# totalHammingDistance
# trappingRainWater
# treeOfCoprimes
# triangle
# triplesWithBitwiseANDEqualToZero
# truncateSentence
# tupleWithSameProduct
# twoArraysEqualByReversingSubArrays
# twoCityScheduling
# twoSum
# uglyNumber
# uniqueBinarySearchTrees
# uniqueEmailAddresses
# uniqueMorseCodeWords
# uniqueNumberOfOccurrences
# uniquePaths
# UTF8Validation
# validateBinarySearchTree
# validNumber
# validPalindrome
# validParentheses
# validPerfectSquare
# validSudoku
# verifyPreorderSerializationOfABinaryTree
# verticalOrderTraversalOfABinaryTree
# videoStitching
# waysToSplitArrayIntoThreeSubarrays
# wiggleSort
# wiggleSubsequence
# wildcardMatching
# wordBreak
# wordLadder
# wordPattern
# wordSearch
# zigZagConversion
#
# github_code/algorithms/cpp/3Sum:
#
# github_code/algorithms/cpp/3SumClosest:
#
# github_code/algorithms/cpp/4Sum:
#
# github_code/algorithms/cpp/accountsMerge:
#
# github_code/algorithms/cpp/addAndSearchWord:
#
# github_code/algorithms/cpp/addBinary:
#
# github_code/algorithms/cpp/addDigits:
#
# github_code/algorithms/cpp/additiveNumber:
#
# github_code/algorithms/cpp/addStrings:
#
# github_code/algorithms/cpp/addToArrayFormOfInteger:
#
# github_code/algorithms/cpp/addTwoNumbers:
#
# github_code/algorithms/cpp/anagrams:
#
# github_code/algorithms/cpp/arithmeticSlices:
#
# github_code/algorithms/cpp/backspaceStringCompare:
#
# github_code/algorithms/cpp/balancedBinaryTree:
#
# github_code/algorithms/cpp/basicCalculator:
#
# github_code/algorithms/cpp/bestTimeToBuyAndSellStock:
#
# github_code/algorithms/cpp/binarySearchTreeIterator:
#
# github_code/algorithms/cpp/binaryTreeInorderTraversal:
#
# github_code/algorithms/cpp/binaryTreeLevelOrderTraversal:
#
# github_code/algorithms/cpp/binaryTreeMaximumPathSum:
#
# github_code/algorithms/cpp/binaryTreePaths:
#
# github_code/algorithms/cpp/binaryTreePostorderTraversal:
#
# github_code/algorithms/cpp/binaryTreePreorderTraversal:
#
# github_code/algorithms/cpp/binaryTreeRightSideView:
#
# github_code/algorithms/cpp/binaryTreeUpsideDown:
#
# github_code/algorithms/cpp/binaryTreeZigzagLevelOrderTraversal:
#
# github_code/algorithms/cpp/binaryWatch:
#
# github_code/algorithms/cpp/bitwiseANDOfNumbersRange:
#
# github_code/algorithms/cpp/brokenCalculator:
#
# github_code/algorithms/cpp/buddyStrings:
#
# github_code/algorithms/cpp/buildingBoxes:
#
# github_code/algorithms/cpp/bulbSwitcher:
#
# github_code/algorithms/cpp/bullsAndCows:
#
# github_code/algorithms/cpp/burstBalloons:
#
# github_code/algorithms/cpp/calculateMoneyInLeetcodeBank:
#
# github_code/algorithms/cpp/candy:
#
# github_code/algorithms/cpp/checkIfArrayIsSortedAndRotated:
#
# github_code/algorithms/cpp/checkIfBinaryStringHasAtMostOneSegmentOfOnes:
#
# github_code/algorithms/cpp/checkIfNumberIsASumOfPowersOfThree:
#
# github_code/algorithms/cpp/checkIfOneStringSwapCanMakeStringsEqual:
#
# github_code/algorithms/cpp/checkIfTheSentenceIsPangram:
#
# github_code/algorithms/cpp/checkIfWordEqualsSummationOfTwoWords:
#
# github_code/algorithms/cpp/climbStairs:
#
# github_code/algorithms/cpp/cloneGraph:
#
# github_code/algorithms/cpp/closestDessertCost:
#
# github_code/algorithms/cpp/closestRoom:
#
# github_code/algorithms/cpp/closestSubsequenceSum:
#
# github_code/algorithms/cpp/coinChange:
#
# github_code/algorithms/cpp/combinations:
#
# github_code/algorithms/cpp/combinationSum:
#
# github_code/algorithms/cpp/combinationSumIV:
#
# github_code/algorithms/cpp/compareStringsByFrequencyOfTheSmallestCharacter:
#
# github_code/algorithms/cpp/compareVersionNumbers:
#
# github_code/algorithms/cpp/constructBinaryTreeFromInorderAndPostorderTraversal:
#
# github_code/algorithms/cpp/constructBinaryTreeFromPreorderAndInorderTraversal:
#
# github_code/algorithms/cpp/constructTheLexicographicallyLargestValidSequence:
#
# github_code/algorithms/cpp/containerWithMostWater:
#
# github_code/algorithms/cpp/containsDuplicate:
#
# github_code/algorithms/cpp/convertANumberToHexadecimal:
#
# github_code/algorithms/cpp/convertSortedArrayToBinarySearchTree:
#
# github_code/algorithms/cpp/convertSortedListToBinarySearchTree:
#
# github_code/algorithms/cpp/copyListWithRandomPointer:
#
# github_code/algorithms/cpp/countAndSay:
#
# github_code/algorithms/cpp/countCompleteTreeNodes:
#
# github_code/algorithms/cpp/countGoodMeals:
#
# github_code/algorithms/cpp/countingBits:
#
# github_code/algorithms/cpp/countItemsMatchingARule:
#
# github_code/algorithms/cpp/countNicePairsInAnArray:
#
# github_code/algorithms/cpp/countNumberOfHomogenousSubstrings:
#
# github_code/algorithms/cpp/countNumbersWithUniqueDigits:
#
# github_code/algorithms/cpp/countOddNumbersInAnIntervalRange:
#
# github_code/algorithms/cpp/countOfRangeSum:
#
# github_code/algorithms/cpp/countOfSmallerNumbersAfterSelf:
#
# github_code/algorithms/cpp/countPairsOfNodes:
#
# github_code/algorithms/cpp/countPairsWithXorInARange:
#
# github_code/algorithms/cpp/countPrimes:
#
# github_code/algorithms/cpp/courseSchedule:
# non-recursive
#
# github_code/algorithms/cpp/courseSchedule/non-recursive:
#
# github_code/algorithms/cpp/cousinsInBinaryTree:
#
# github_code/algorithms/cpp/createMaximumNumber:
#
# github_code/algorithms/cpp/decodeString:
#
# github_code/algorithms/cpp/decodeWays:
#
# github_code/algorithms/cpp/decodeXORedPermutation:
#
# github_code/algorithms/cpp/deleteNodeInALinkedList:
#
# github_code/algorithms/cpp/designAuthenticationManager:
#
# github_code/algorithms/cpp/detectCapital:
#
# github_code/algorithms/cpp/determineColorOfAChessboardSquare:
#
# github_code/algorithms/cpp/diameterOfBinaryTree:
#
# github_code/algorithms/cpp/differentWaysToAddParentheses:
#
# github_code/algorithms/cpp/distinctSubsequences:
#
# github_code/algorithms/cpp/distributeCoinsInBinaryTree:
#
# github_code/algorithms/cpp/divideTwoInt:
#
# github_code/algorithms/cpp/dungeonGame:
#
# github_code/algorithms/cpp/editDistance:
#
# github_code/algorithms/cpp/eggDropWith2EggsAndNFloors:
#
# github_code/algorithms/cpp/eliminationGame:
#
# github_code/algorithms/cpp/equalSumArraysWithMinimumNumberOfOperations:
#
# github_code/algorithms/cpp/evaluateDivision:
#
# github_code/algorithms/cpp/evaluateReversePolishNotation:
#
# github_code/algorithms/cpp/evaluateTheBracketPairsOfAString:
#
# github_code/algorithms/cpp/excelSheetColumnNumber:
#
# github_code/algorithms/cpp/excelSheetColumnTitle:
#
# github_code/algorithms/cpp/expressionAddOperators:
#
# github_code/algorithms/cpp/factorialTrailingZeroes:
#
# github_code/algorithms/cpp/fibonacciNumber:
#
# github_code/algorithms/cpp/filterRestaurantsByVeganFriendlyPriceAndDistance:
#
# github_code/algorithms/cpp/findAllAnagramsInAString:
#
# github_code/algorithms/cpp/findCenterOfStarGraph:
#
# github_code/algorithms/cpp/findingMkAverage:
#
# github_code/algorithms/cpp/findingTheUsersActiveMinutes:
#
# github_code/algorithms/cpp/findKthLargestXorCoordinateValue:
#
# github_code/algorithms/cpp/findMedianFromDataStream:
#
# github_code/algorithms/cpp/findMinimumInRotatedSortedArray:
#
# github_code/algorithms/cpp/findNearestPointThatHasTheSameXOrYCoordinate:
#
# github_code/algorithms/cpp/findPeakElement:
#
# github_code/algorithms/cpp/findTheDifference:
#
# github_code/algorithms/cpp/findTheDuplicateNumber:
#
# github_code/algorithms/cpp/findTheHighestAltitude:
#
# github_code/algorithms/cpp/findTheWinnerOfAnArrayGame:
#
# github_code/algorithms/cpp/findTheWinnerOfTheCircularGame:
#
# github_code/algorithms/cpp/FindValidMatrixGivenRowAndColumnSums:
#
# github_code/algorithms/cpp/findXorSumOfAllPairsBitwiseAnd:
#
# github_code/algorithms/cpp/firstBadVersion:
#
# github_code/algorithms/cpp/firstMissingPositive:
#
# github_code/algorithms/cpp/firstUniqueCharacterInAString:
#
# github_code/algorithms/cpp/fizzBuzz:
#
# github_code/algorithms/cpp/flattenBinaryTreeToLinkedList:
#
# github_code/algorithms/cpp/flattenNestedListIterator:
#
# github_code/algorithms/cpp/formArrayByConcatenatingSubarraysOfAnotherArray:
#
# github_code/algorithms/cpp/fractionToRecurringDecimal:
#
# github_code/algorithms/cpp/frequencyOfTheMostFrequentElement:
#
# github_code/algorithms/cpp/friendCircles:
#
# github_code/algorithms/cpp/frogJump:
#
# github_code/algorithms/cpp/gameOfLife:
#
# github_code/algorithms/cpp/gasStation:
#
# github_code/algorithms/cpp/generateParentheses:
#
# github_code/algorithms/cpp/grayCode:
#
# github_code/algorithms/cpp/greatestCommonDivisorOfStrings:
#
# github_code/algorithms/cpp/happyNumber:
#
# github_code/algorithms/cpp/h-Index:
#
# github_code/algorithms/cpp/houseRobber:
#
# github_code/algorithms/cpp/implementQueueUsingStacks:
#
# github_code/algorithms/cpp/implementStackUsingQueues:
#
# github_code/algorithms/cpp/implementTriePrefixTree:
#
# github_code/algorithms/cpp/increasingTripletSubsequence:
#
# github_code/algorithms/cpp/incrementalMemoryLeak:
#
# github_code/algorithms/cpp/insertDeleteGetRandom:
#
# github_code/algorithms/cpp/insertInterval:
#
# github_code/algorithms/cpp/insertionSortList:
#
# github_code/algorithms/cpp/integerBreak:
#
# github_code/algorithms/cpp/integerReplacement:
#
# github_code/algorithms/cpp/integerToEnglishWords:
#
# github_code/algorithms/cpp/integerToRoman:
#
# github_code/algorithms/cpp/interleavingString:
#
# github_code/algorithms/cpp/intersectionOfTwoArrays:
#
# github_code/algorithms/cpp/intersectionOfTwoLinkedLists:
#
# github_code/algorithms/cpp/intervalListIntersectons:
#
# github_code/algorithms/cpp/invertBinaryTree:
#
# github_code/algorithms/cpp/islandPerimeter:
#
# github_code/algorithms/cpp/isomorphicStrings:
#
# github_code/algorithms/cpp/isSubsequence:
#
# github_code/algorithms/cpp/jewelsAndStones:
#
# github_code/algorithms/cpp/jumpGame:
#
# github_code/algorithms/cpp/kthLargestElementInAnArray:
#
# github_code/algorithms/cpp/kthSmallestElementInaBST:
#
# github_code/algorithms/cpp/largestColorValueInADirectedGraph:
#
# github_code/algorithms/cpp/largestMergeOfTwoStrings:
#
# github_code/algorithms/cpp/largestNumber:
#
# github_code/algorithms/cpp/largestNumberAfterMutatingSubstring:
#
# github_code/algorithms/cpp/largestPerimeterTriangle:
#
# github_code/algorithms/cpp/largestRectangleInHistogram:
#
# github_code/algorithms/cpp/largestSubmatrixWithRearrangements:
#
# github_code/algorithms/cpp/largestSubstringBetweenTwoEqualCharacters:
#
# github_code/algorithms/cpp/latestTimeByReplacingHiddenDigits:
#
# github_code/algorithms/cpp/lengthOfLastWord:
#
# github_code/algorithms/cpp/letterCombinationsOfAPhoneNumber:
#
# github_code/algorithms/cpp/lexicographicallySmallestStringAfterApplyingOperations:
#
# github_code/algorithms/cpp/lexicographicalNumbers:
#
# github_code/algorithms/cpp/linkedListCycle:
#
# github_code/algorithms/cpp/linkedListRandomNode:
#
# github_code/algorithms/cpp/longerContiguousSegmentsOfOnesThanZeros:
#
# github_code/algorithms/cpp/longestAbsoluteFilePath:
#
# github_code/algorithms/cpp/longestCommonPrefix:
#
# github_code/algorithms/cpp/longestConsecutiveSequence:
#
# github_code/algorithms/cpp/longestIncreasingPathInAMatrix:
#
# github_code/algorithms/cpp/longestIncreasingSubsequence:
#
# github_code/algorithms/cpp/longestNiceSubstring:
#
# github_code/algorithms/cpp/longestPalindrome:
#
# github_code/algorithms/cpp/longestPalindromicSubsequence:
#
# github_code/algorithms/cpp/longestPalindromicSubstring:
#
# github_code/algorithms/cpp/longestSubstringOfAllVowelsInOrder:
#
# github_code/algorithms/cpp/longestSubstringWithAtLeastKRepeatingCharacters:
#
# github_code/algorithms/cpp/longestSubstringWithAtMostTwoDistinctCharacters:
#
# github_code/algorithms/cpp/longestSubstringWithoutRepeatingCharacters:
#
# github_code/algorithms/cpp/longestTurbulentSubarray:
#
# github_code/algorithms/cpp/longestValidParentheses:
#
# github_code/algorithms/cpp/lowestCommonAncestorOfABinarySearchTree:
#
# github_code/algorithms/cpp/lowestCommonAncestorOfABinaryTree:
#
# github_code/algorithms/cpp/LRUCache:
#
# github_code/algorithms/cpp/majorityElement:
#
# github_code/algorithms/cpp/makeTheXorOfAllSegmentsEqualToZero:
#
# github_code/algorithms/cpp/mapOfHighestPeak:
#
# github_code/algorithms/cpp/matrixCellsInDistanceOrder:
#
# github_code/algorithms/cpp/maxAreaOfIsland:
#
# github_code/algorithms/cpp/maximalRectangle:
#
# github_code/algorithms/cpp/maximalSquare:
#
# github_code/algorithms/cpp/maximizeNumberOfNiceDivisors:
#
# github_code/algorithms/cpp/maximizePalindromeLengthFromSubsequences:
#
# github_code/algorithms/cpp/maximizeScoreAfterNOperations:
#
# github_code/algorithms/cpp/maximumAbsoluteSumOfAnySubarray:
#
# github_code/algorithms/cpp/maximumAscendingSubarraySum:
#
# github_code/algorithms/cpp/maximumAveragePassRatio:
#
# github_code/algorithms/cpp/maximumAverageSubarray:
#
# github_code/algorithms/cpp/maximumBuildingHeight:
#
# github_code/algorithms/cpp/maximumDepthOfBinaryTree:
#
# github_code/algorithms/cpp/maximumDistanceBetweenAPairOfValues:
#
# github_code/algorithms/cpp/maximumElementAfterDecreasingAndRearranging:
#
# github_code/algorithms/cpp/maximumErasureValue:
#
# github_code/algorithms/cpp/maximumGap:
#
# github_code/algorithms/cpp/maximumIceCreamBars:
#
# github_code/algorithms/cpp/maximumNumberOfBallsInABox:
#
# github_code/algorithms/cpp/maximumNumberOfConsecutiveValuesYouCanMake:
#
# github_code/algorithms/cpp/maximumNumberOfEventsThatCanBeAttended:
#
# github_code/algorithms/cpp/maximumNumberOfGroupsGettingFreshDonuts:
#
# github_code/algorithms/cpp/maximumNumberOfWordsYouCanType:
#
# github_code/algorithms/cpp/maximumPopulationYear:
#
# github_code/algorithms/cpp/maximumProductOfTwoElementsInAnArray:
#
# github_code/algorithms/cpp/maximumProductOfWordLengths:
#
# github_code/algorithms/cpp/maximumProductSubarray:
#
# github_code/algorithms/cpp/maximumScoreFromPerformingMultiplicationOperations:
#
# github_code/algorithms/cpp/maximumScoreFromRemovingStones:
#
# github_code/algorithms/cpp/maximumScoreFromRemovingSubstrings:
#
# github_code/algorithms/cpp/maximumScoreOfAGoodSubarray:
#
# github_code/algorithms/cpp/maximumSubArray:
#
# github_code/algorithms/cpp/maximumSubarrayMinProduct:
#
# github_code/algorithms/cpp/maximumUnitsOnATruck:
#
# github_code/algorithms/cpp/maximumValueAfterInsertion:
#
# github_code/algorithms/cpp/maximumValueAtAGivenIndexInABoundedArray:
#
# github_code/algorithms/cpp/maximumXorForEachQuery:
#
# github_code/algorithms/cpp/maxPointsOnALine:
#
# github_code/algorithms/cpp/medianOfTwoSortedArrays:
#
# github_code/algorithms/cpp/mergeIntervals:
#
# github_code/algorithms/cpp/mergeKSortedLists:
#
# github_code/algorithms/cpp/mergeStringsAlternately:
#
# github_code/algorithms/cpp/mergeTwoSortedArray:
#
# github_code/algorithms/cpp/mergeTwoSortedList:
#
# github_code/algorithms/cpp/minCostClimbingStairs:
#
# github_code/algorithms/cpp/minimizeMaximumPairSumInArray:
#
# github_code/algorithms/cpp/minimumAbsoluteSumDifference:
#
# github_code/algorithms/cpp/minimumAdjacentSwapsToReachTheKthSmallestNumber:
#
# github_code/algorithms/cpp/minimumASCIIDeleteSumForTwoStrings:
#
# github_code/algorithms/cpp/minimumChangesToMakeAlternatingBinaryString:
#
# github_code/algorithms/cpp/minimumCostForTickets:
#
# github_code/algorithms/cpp/minimumDegreeOfAConnectedTrioInAGraph:
#
# github_code/algorithms/cpp/minimumDepthOfBinaryTree:
#
# github_code/algorithms/cpp/minimumDistanceToTheTargetElement:
#
# github_code/algorithms/cpp/minimumElementsToAddToFormAGivenSum:
#
# github_code/algorithms/cpp/minimumFallingPathSum:
#
# github_code/algorithms/cpp/minimumHeightTrees:
#
# github_code/algorithms/cpp/minimumInsertionsToBalanceAParenthesesString:
#
# github_code/algorithms/cpp/minimumIntervalToIncludeEachQuery:
#
# github_code/algorithms/cpp/minimumLengthOfStringAfterDeletingSimilarEnds:
#
# github_code/algorithms/cpp/minimumLimitOfBallsInABag:
#
# github_code/algorithms/cpp/minimumNumberOfOperationsToMoveAllBallsToEachBox:
#
# github_code/algorithms/cpp/minimumNumberOfOperationsToReinitializeAPermutation:
#
# github_code/algorithms/cpp/minimumNumberOfPeopleToTeach:
#
# github_code/algorithms/cpp/minimumOperationsToMakeArrayEqual:
#
# github_code/algorithms/cpp/minimumOperationsToMakeTheArrayIncreasing:
#
# github_code/algorithms/cpp/minimumPathSum:
#
# github_code/algorithms/cpp/minimumSidewayJumps:
#
# github_code/algorithms/cpp/minimumSizeSubarraySum:
#
# github_code/algorithms/cpp/minimumSpeedToArriveOnTime:
#
# github_code/algorithms/cpp/minimumWindowSubstring:
#
# github_code/algorithms/cpp/miniParser:
#
# github_code/algorithms/cpp/minStack:
#
# github_code/algorithms/cpp/mirrorReflection:
#
# github_code/algorithms/cpp/missingNumber:
#
# github_code/algorithms/cpp/missingRanges:
#
# github_code/algorithms/cpp/mostCommonWord:
#
# github_code/algorithms/cpp/moveZeroes:
#
# github_code/algorithms/cpp/multiplyStrings:
#
# github_code/algorithms/cpp/nextPermutation:
#
# github_code/algorithms/cpp/nimGame:
#
# github_code/algorithms/cpp/nQueens:
#
# github_code/algorithms/cpp/nRepeatedElementInSize2NArray:
#
# github_code/algorithms/cpp/nthDigit:
#
# github_code/algorithms/cpp/numberOf1Bits:
#
# github_code/algorithms/cpp/numberOfDifferentIntegersInAString:
#
# github_code/algorithms/cpp/numberOfDifferentSubsequencesGcds:
#
# github_code/algorithms/cpp/numberOfDigitOne:
#
# github_code/algorithms/cpp/numberOfGoodWaysToSplitAString:
#
# github_code/algorithms/cpp/numberOfIslands:
#
# github_code/algorithms/cpp/numberOfOrdersInTheBacklog:
#
# github_code/algorithms/cpp/numberOfRecentCalls:
#
# github_code/algorithms/cpp/numberOfRectanglesThatCanFormTheLargestSquare:
#
# github_code/algorithms/cpp/numberOfRestrictedPathsFromFirstToLastNode:
#
# github_code/algorithms/cpp/numberOfStudentsUnableToEatLunch:
#
# github_code/algorithms/cpp/numberOfSubArraysWithOddSum:
#
# github_code/algorithms/cpp/numberOfSubstringsWithOnly1s:
#
# github_code/algorithms/cpp/NumberOfWaysToSplitString:
#
# github_code/algorithms/cpp/oddEvenLinkedList:
#
# github_code/algorithms/cpp/oneEditDistance:
#
# github_code/algorithms/cpp/palindromeLinkedList:
#
# github_code/algorithms/cpp/palindromeNumber:
#
# github_code/algorithms/cpp/palindromePairs:
#
# github_code/algorithms/cpp/palindromePartitioning:
#
# github_code/algorithms/cpp/palindromicSubstrings:
#
# github_code/algorithms/cpp/partitionEqualSubsetSum:
#
# github_code/algorithms/cpp/partitionList:
#
# github_code/algorithms/cpp/pascalTriangle:
#
# github_code/algorithms/cpp/patchingArray:
#
# github_code/algorithms/cpp/pathSum:
#
# github_code/algorithms/cpp/peakIndexInAMountainArray:
#
# github_code/algorithms/cpp/peekingIterator:
#
# github_code/algorithms/cpp/perfectRectangle:
#
# github_code/algorithms/cpp/perfectSquares:
#
# github_code/algorithms/cpp/permutations:
#
# github_code/algorithms/cpp/permutationSequence:
#
# github_code/algorithms/cpp/plusOne:
#
# github_code/algorithms/cpp/populatingNextRightPointersInEachNode:
#
# github_code/algorithms/cpp/pow:
#
# github_code/algorithms/cpp/powerOfFour:
#
# github_code/algorithms/cpp/powerOfThree:
#
# github_code/algorithms/cpp/powerOfTwo:
#
# github_code/algorithms/cpp/processTasksUsingServers:
#
# github_code/algorithms/cpp/productOfArrayExceptSelf:
#
# github_code/algorithms/cpp/queriesOnNumberOfPointsInsideACircle:
#
# github_code/algorithms/cpp/queueReconstructionByHeight:
#
# github_code/algorithms/cpp/randomPickIndex:
#
# github_code/algorithms/cpp/randomPointInNonOverlappingRectangles:
#
# github_code/algorithms/cpp/rangeSumQuery2D-Immutable:
#
# github_code/algorithms/cpp/rangeSumQuery-Immutable:
# rangeSumQuery-Mutable
#
# github_code/algorithms/cpp/rangeSumQuery-Immutable/rangeSumQuery-Mutable:
#
# github_code/algorithms/cpp/ransomNote:
#
# github_code/algorithms/cpp/readNCharactersGivenRead4:
#
# github_code/algorithms/cpp/reconstructItinerary:
#
# github_code/algorithms/cpp/recoverATreeFromPreorderTraversal:
#
# github_code/algorithms/cpp/recoverBinarySearchTree:
#
# github_code/algorithms/cpp/rectangleArea:
#
# github_code/algorithms/cpp/reformatPhoneNumber:
#
# github_code/algorithms/cpp/regularExpressionMatching:
#
# github_code/algorithms/cpp/removeDuplicateLetters:
#
# github_code/algorithms/cpp/removeDuplicatesFromSortedArray:
#
# github_code/algorithms/cpp/removeDuplicatesFromSortedList:
#
# github_code/algorithms/cpp/removeElement:
#
# github_code/algorithms/cpp/removeInvalidParentheses:
#
# github_code/algorithms/cpp/removeKDigits:
#
# github_code/algorithms/cpp/removeLinkedListElements:
#
# github_code/algorithms/cpp/removeNthNodeFromEndOfList:
#
# github_code/algorithms/cpp/reorderList:
#
# github_code/algorithms/cpp/repeatedDNASequences:
#
# github_code/algorithms/cpp/replaceAllDigitsWithCharacters:
#
# github_code/algorithms/cpp/restoreIPAddresses:
#
# github_code/algorithms/cpp/restoreTheArrayFromAdjacentPairs:
#
# github_code/algorithms/cpp/reverseBits:
#
# github_code/algorithms/cpp/reverseInteger:
#
# github_code/algorithms/cpp/reverseLinkedList:
#
# github_code/algorithms/cpp/reverseNodesInKGroup:
#
# github_code/algorithms/cpp/reverseString:
#
# github_code/algorithms/cpp/reverseVowelsOfAString:
#
# github_code/algorithms/cpp/reverseWordsInAString:
#
# github_code/algorithms/cpp/romanToInteger:
#
# github_code/algorithms/cpp/rotateArray:
#
# github_code/algorithms/cpp/rotateFunction:
#
# github_code/algorithms/cpp/rotateImage:
#
# github_code/algorithms/cpp/rotateList:
#
# github_code/algorithms/cpp/rotatingTheBox:
#
# github_code/algorithms/cpp/sameTree:
#
# github_code/algorithms/cpp/satisfiabilityOfEqualityEquations:
#
# github_code/algorithms/cpp/scrambleString:
#
# github_code/algorithms/cpp/search2DMatrix:
#
# github_code/algorithms/cpp/searchForRange:
#
# github_code/algorithms/cpp/searchInRotatedSortedArray:
#
# github_code/algorithms/cpp/searchInsertPosition:
#
# github_code/algorithms/cpp/seatReservationManager:
#
# github_code/algorithms/cpp/secondLargestDigitInAString:
#
# github_code/algorithms/cpp/sentenceScreenFitting:
#
# github_code/algorithms/cpp/sentenceSimilarity:
#
# github_code/algorithms/cpp/serializeAndDeserializeBinaryTree:
#
# github_code/algorithms/cpp/setMatrixZeroes:
#
# github_code/algorithms/cpp/shortEncodingOfWords:
#
# github_code/algorithms/cpp/shortestPalindrome:
#
# github_code/algorithms/cpp/shuffleAnArray:
#
# github_code/algorithms/cpp/shuffleString:
#
# github_code/algorithms/cpp/shuffleTheArray:
#
# github_code/algorithms/cpp/signOfTheProductOfAnArray:
#
# github_code/algorithms/cpp/simplifyPath:
#
# github_code/algorithms/cpp/singleNumber:
#
# github_code/algorithms/cpp/singleThreadedCpu:
#
# github_code/algorithms/cpp/slidingWindowMaximum:
#
# github_code/algorithms/cpp/smallestStringStartingFromLeaf:
#
# github_code/algorithms/cpp/sortArrayByParity:
#
# github_code/algorithms/cpp/sortColors:
#
# github_code/algorithms/cpp/sortingTheSentence:
#
# github_code/algorithms/cpp/sortList:
#
# github_code/algorithms/cpp/spiralMatrix:
#
# github_code/algorithms/cpp/splitArrayLargestSum:
#
# github_code/algorithms/cpp/splittingAStringIntoDescendingConsecutiveValues:
#
# github_code/algorithms/cpp/sqrt:
#
# github_code/algorithms/cpp/squaresOfASortedArray:
#
# github_code/algorithms/cpp/stringToIntegerAtoi:
#
# github_code/algorithms/cpp/stringWithoutAAAOrBBB:
#
# github_code/algorithms/cpp/strStr:
#
# github_code/algorithms/cpp/subsets:
#
# github_code/algorithms/cpp/substringsOfSizeThreeWithDistinctCharacters:
#
# github_code/algorithms/cpp/substringWithConcatenationOfAllWords:
#
# github_code/algorithms/cpp/sudokuSolver:
#
# github_code/algorithms/cpp/summaryRanges:
#
# github_code/algorithms/cpp/sumOfBeautyOfAllSubstrings:
#
# github_code/algorithms/cpp/sumOfDigitsInBaseK:
#
# github_code/algorithms/cpp/sumOfDigitsOfStringAfterConvert:
#
# github_code/algorithms/cpp/sumOfEvenNumbersAfterQueries:
#
# github_code/algorithms/cpp/sumOfFlooredPairs:
#
# github_code/algorithms/cpp/sumOfLeftLeaves:
#
# github_code/algorithms/cpp/sumOfTwoIntegers:
#
# github_code/algorithms/cpp/sumOfUniqueElements:
#
# github_code/algorithms/cpp/sumRootToLeafNumber:
#
# github_code/algorithms/cpp/superUglyNumber:
#
# github_code/algorithms/cpp/surroundedRegions:
#
# github_code/algorithms/cpp/swapNodesInPairs:
#
# github_code/algorithms/cpp/symmetricTree:
#
# github_code/algorithms/cpp/targetSum:
#
# github_code/algorithms/cpp/textJustification:
#
# github_code/algorithms/cpp/theSkylineProblem:
#
# github_code/algorithms/cpp/thirdMaximumNumber:
#
# github_code/algorithms/cpp/thousandSeparator:
#
# github_code/algorithms/cpp/threeConsecutiveOdds:
#
# github_code/algorithms/cpp/timeBasedKeyValueStore:
#
# github_code/algorithms/cpp/timeNeededToInformAllEmployees:
#
# github_code/algorithms/cpp/topKFrequentElements:
#
# github_code/algorithms/cpp/totalHammingDistance:
#
# github_code/algorithms/cpp/trappingRainWater:
#
# github_code/algorithms/cpp/treeOfCoprimes:
#
# github_code/algorithms/cpp/triangle:
#
# github_code/algorithms/cpp/triplesWithBitwiseANDEqualToZero:
#
# github_code/algorithms/cpp/truncateSentence:
#
# github_code/algorithms/cpp/tupleWithSameProduct:
#
# github_code/algorithms/cpp/twoArraysEqualByReversingSubArrays:
#
# github_code/algorithms/cpp/twoCityScheduling:
#
# github_code/algorithms/cpp/twoSum:
#
# github_code/algorithms/cpp/uglyNumber:
#
# github_code/algorithms/cpp/uniqueBinarySearchTrees:
#
# github_code/algorithms/cpp/uniqueEmailAddresses:
#
# github_code/algorithms/cpp/uniqueMorseCodeWords:
#
# github_code/algorithms/cpp/uniqueNumberOfOccurrences:
#
# github_code/algorithms/cpp/uniquePaths:
#
# github_code/algorithms/cpp/UTF8Validation:
#
# github_code/algorithms/cpp/validateBinarySearchTree:
#
# github_code/algorithms/cpp/validNumber:
#
# github_code/algorithms/cpp/validPalindrome:
#
# github_code/algorithms/cpp/validParentheses:
#
# github_code/algorithms/cpp/validPerfectSquare:
#
# github_code/algorithms/cpp/validSudoku:
#
# github_code/algorithms/cpp/verifyPreorderSerializationOfABinaryTree:
#
# github_code/algorithms/cpp/verticalOrderTraversalOfABinaryTree:
#
# github_code/algorithms/cpp/videoStitching:
#
# github_code/algorithms/cpp/waysToSplitArrayIntoThreeSubarrays:
#
# github_code/algorithms/cpp/wiggleSort:
#
# github_code/algorithms/cpp/wiggleSubsequence:
#
# github_code/algorithms/cpp/wildcardMatching:
#
# github_code/algorithms/cpp/wordBreak:
#
# github_code/algorithms/cpp/wordLadder:
#
# github_code/algorithms/cpp/wordPattern:
#
# github_code/algorithms/cpp/wordSearch:
#
# github_code/algorithms/cpp/zigZagConversion:
#
# github_code/algorithms/golang:
# twoSum
#
# github_code/algorithms/golang/twoSum:
#
# github_code/algorithms/java:
# src
#
# github_code/algorithms/java/src:
# balancedBinaryTree		     myStack
# binarySearchTreeIterator	     palindromeNumber
# binaryTreeBFSTraversal		     powXn
# binaryTreeLevelOrderTraversal	     removeDuplicatesFromSortedArray
# binaryTreeMaximumPathSum	     reverseLinkedList
# binaryTreePreorderTraversal	     reverseLinkedListII
# containerwithmostwater.java	     reverseWordsInAString
# countAndSay			     rotateArray
# dynamicProgramming		     RotateImage
# findMinimumInRotatedSortedArray      search2DMatrix
# findPeakElement			     searchA2DMatrixII
# firstBadVersion			     searchForRange
# inorderSuccessorInBST		     searchInABigSortedArray
# LargestNumberAfterMutatingSubstring  searchInRotatedSortedArray
# lengthOfLastWord		     searchInsertPosition
# lowestCommonAncestorOfABinaryTree    searchRangeInBinarySearchTree
# lruCache			     strStr
# maximumDepthOfBinaryTree	     subsets
# MaxSubArray			     validAnagram
# minStack			     validateBinarySearchTree
# myQueue				     validPalindrome
#
# github_code/algorithms/java/src/balancedBinaryTree:
# balancedBinaryTree.java  balancedBinaryTreeTest.java  TreeNode.java
#
# github_code/algorithms/java/src/binarySearchTreeIterator:
# binarySearchTreeIterator.java  binarySearchTreeIteratorTest.java  TreeNode.java
#
# github_code/algorithms/java/src/binaryTreeBFSTraversal:
# binaryTreeBFSTraversal.java  binaryTreeBFSTraversalTest.java  TreeNode.java
#
# github_code/algorithms/java/src/binaryTreeLevelOrderTraversal:
# binaryTreeLevelOrderTraversal.java  binaryTreeLevelOrderTraversalTest.java  TreeNode.java
#
# github_code/algorithms/java/src/binaryTreeMaximumPathSum:
# binaryTreeMaximumPathSum.java  binaryTreeMaximumPathSumTest.java  TreeNode.java
#
# github_code/algorithms/java/src/binaryTreePreorderTraversal:
# binaryTreePreorderTraversal.java  binaryTreePreorderTraversalTest.java	TreeNode.java
#
# github_code/algorithms/java/src/countAndSay:
# CountAndSay.java  TestCountAndSay.java
#
# github_code/algorithms/java/src/dynamicProgramming:
# climbStairs  minimumPathSum  triangle  uniquePaths
#
# github_code/algorithms/java/src/dynamicProgramming/climbStairs:
# climbStairs.java  climbStairsTest.java
#
# github_code/algorithms/java/src/dynamicProgramming/minimumPathSum:
# minimumPathSum.java  minimumPathSumTest.java
#
# github_code/algorithms/java/src/dynamicProgramming/triangle:
# triangle.java  triangleTest.java
#
# github_code/algorithms/java/src/dynamicProgramming/uniquePaths:
# uniquePathsII.java  uniquePathsIITest.java  uniquePaths.java  uniquePathsTest.java
#
# github_code/algorithms/java/src/findMinimumInRotatedSortedArray:
# findMinimumInRotatedSortedArray.java  findMinimumInRotatedSortedArrayTest.java
#
# github_code/algorithms/java/src/findPeakElement:
# findPeakElement.java  findPeakElementTest.java
#
# github_code/algorithms/java/src/firstBadVersion:
# firstBadVersion.java  firstBadVersionTest.java	VersionControl.java
#
# github_code/algorithms/java/src/inorderSuccessorInBST:
# inorderSuccessorInBST.java  inorderSuccessorInBSTTest.java  TreeNode.java
#
# github_code/algorithms/java/src/LargestNumberAfterMutatingSubstring:
# largestNumberAfterMutatingSubstring.java
#
# github_code/algorithms/java/src/lengthOfLastWord:
# LengthOfLastWord.java  TestLengthOfLastWord.java
#
# github_code/algorithms/java/src/lowestCommonAncestorOfABinaryTree:
# lowestCommonAncestorOfABinaryTree.java	lowestCommonAncestorOfABinaryTreeTest.java  TreeNode.java
#
# github_code/algorithms/java/src/lruCache:
# LRUCache.java  LRUCacheTest.java
#
# github_code/algorithms/java/src/maximumDepthOfBinaryTree:
# maximumDepthOfBinaryTree.java  maximumDepthOfBinaryTreeTest.java  TreeNode.java
#
# github_code/algorithms/java/src/MaxSubArray:
# MaxSubarray.java
#
# github_code/algorithms/java/src/minStack:
# MinStack.java  TestMinStack.java
#
# github_code/algorithms/java/src/myQueue:
# MyQueue.java  TestMyQueue.java
#
# github_code/algorithms/java/src/myStack:
# MyStack.java  TestMyStack.java
#
# github_code/algorithms/java/src/palindromeNumber:
# PalindromeNumber.java  TestPalindromeNumber.java
#
# github_code/algorithms/java/src/powXn:
# PowXn.java  TestPowXn.java
#
# github_code/algorithms/java/src/removeDuplicatesFromSortedArray:
# RemoveDuplicatesFromSortedArray.java  TestRemoveDuplicates.java
#
# github_code/algorithms/java/src/reverseLinkedList:
# ListNode.java  ReverseLinkedList.java  TestReverseLinkedList.java
#
# github_code/algorithms/java/src/reverseLinkedListII:
# ListNode.java  ReverseLinkedListII.java  TestReverseLinkedListII.java
#
# github_code/algorithms/java/src/reverseWordsInAString:
# ReverseWordsInAString.java  TestReverseWordsInAString.java
#
# github_code/algorithms/java/src/rotateArray:
# RotateArray.java  TestRotateArray.java
#
# github_code/algorithms/java/src/RotateImage:
# rotateImage.java
#
# github_code/algorithms/java/src/search2DMatrix:
# search2DMatrix.java  search2DMatrixTest.java
#
# github_code/algorithms/java/src/searchA2DMatrixII:
# SearchA2DMatrixII.java	Test_240.java
#
# github_code/algorithms/java/src/searchForRange:
# searchForRange.java  searchForRangeTest.java
#
# github_code/algorithms/java/src/searchInABigSortedArray:
# searchInABigSortedArray.java  searchInABigSortedArrayTest.java
#
# github_code/algorithms/java/src/searchInRotatedSortedArray:
# searchInRotatedSortedArray.java  searchInRotatedSortedArrayTest.java
#
# github_code/algorithms/java/src/searchInsertPosition:
# searchInsertPosition.java  searchInsertPositionTest.java
#
# github_code/algorithms/java/src/searchRangeInBinarySearchTree:
# searchRangeInBinarySearchTree.java  searchRangeInBinarySearchTreeTest.java  TreeNode.java
#
# github_code/algorithms/java/src/strStr:
# strStr.java  StrStrKmp.java  strStrTest.java  TestStrStrKmp.java
#
# github_code/algorithms/java/src/subsets:
# subsetsII.java	subsetsIITest.java  subsets.java  subsetsTest.java
#
# github_code/algorithms/java/src/validAnagram:
# TestValidAnagram.java  ValidAnagram.java
#
# github_code/algorithms/java/src/validateBinarySearchTree:
# TreeNode.java  validateBinarySearchTree.java  validateBinarySearchTreeTest.java
#
# github_code/algorithms/java/src/validPalindrome:
# TestValidPalindrome.java  ValidPalindrome.java
#
# github_code/algorithms/python:
# 1-bitAnd2-bitCharacters				     MaximizeDistanceToClosestPerson
# AddOneRowToTree					     MaximumAverageSubarrayI
# BinarySearchTreeIterator			     MaximumProductOfThreeNumbers
# BinaryTreePostorderTraversal			     MaximumWidthOfBinaryTree
# BinaryTreeTilt					     MiddleOfTheLinkedList
# BinaryTreeZigzagLevelOrderTraversal		     MinCostClimbingStairs
# CheckCompletenessOfABinaryTree			     Non-decreasingArray
# ConstructBinaryTreeFromInorderAndPostorderTraversal  NumberOfIslands
# ConstructBinaryTreeFromPreorderAndInorderTraversal   PancakeSorting
# ContainsDuplicateII				     PartitionList
# ContainsDuplicateIII				     PathSumII
# ConvertBSTtoGreaterTree				     PathSumIII
# CopyListWithRandomPointer			     PopulatingNextRightPointersInEachNode
# CountCompleteTreeNodes				     PopulatingNextRightPointersInEachNodeII
# DeleteNodeInABST				     PositionsOfLargeGroups
# DiameterOfBinaryTree				     PrintBinaryTree
# DifferentWaysToAddParentheses			     RedundantConnection
# FibonacciNumber					     RemoveDuplicatesFromSortedListII
# FindDuplicateSubtrees				     RemoveNthNodeFromEndOfList
# FindTheDuplicateNumber				     ReorderList
# firstMissingPositive				     RevealCardsInIncreasingOrder
# FlattenBinaryTreeToLinkedList			     ReverseLinkedListII
# FlipBinaryTreeToMatchPreorderTraversal		     SearchA2DMatrixII
# FlipEquivalentBinaryTrees			     SecondMinimumNodeInABinaryTree
# HappyNumber					     SerializeAndDeserializeBST
# HouseRobber					     ShortestUnsortedContinuousSubarray
# HouseRobberIII					     SingleNumberII
# ImageSmoother					     SortList
# InsertionSortList				     SquaresOfSortedArray
# jumpGame					     Subsets
# K-diffPairsInAnArray				     SubtreeOfAnotherTree
# KthSmallestElementInABST			     SumOfLeftLeaves
# LargestNumberAtLeastTwiceOfOthers		     SumRootToLeafNumbers
# LargestPerimeterTriangle			     SwimInRisingWater
# LinkedListCycleII				     ThirdMaximumNumber
# LongestConsecutiveSequence			     UniqueBinarySearchTrees
# LongestContinuousIncreasingSubsequence		     UniqueBinarySearchTreesII
# LongestTurbulentSubarray			     uniquePaths
# LongestUnivaluePath				     ValidateBinarySearchTree
# LowestCommonAncestorOfABinarySearchTree		     ValidMountainArray
# LowestCommonAncestorOfABinaryTree		     XOfAKindInADeckOfCards
#
# github_code/algorithms/python/1-bitAnd2-bitCharacters:
# isOneBitCharacter.py
#
# github_code/algorithms/python/AddOneRowToTree:
# addOneRow.py
#
# github_code/algorithms/python/BinarySearchTreeIterator:
# BSTIterator.py
#
# github_code/algorithms/python/BinaryTreePostorderTraversal:
# postorderTraversal.py
#
# github_code/algorithms/python/BinaryTreeTilt:
# findTilt.py
#
# github_code/algorithms/python/BinaryTreeZigzagLevelOrderTraversal:
# zigzagLevelOrder.py
#
# github_code/algorithms/python/CheckCompletenessOfABinaryTree:
# isCompleteTree.py
#
# github_code/algorithms/python/ConstructBinaryTreeFromInorderAndPostorderTraversal:
# buildTree.py
#
# github_code/algorithms/python/ConstructBinaryTreeFromPreorderAndInorderTraversal:
# buildTree.py
#
# github_code/algorithms/python/ContainsDuplicateII:
# containsNearbyDuplicate.py
#
# github_code/algorithms/python/ContainsDuplicateIII:
# containsNearbyAlmostDuplicate.py
#
# github_code/algorithms/python/ConvertBSTtoGreaterTree:
# convertBST.py
#
# github_code/algorithms/python/CopyListWithRandomPointer:
# copyRandomList.py
#
# github_code/algorithms/python/CountCompleteTreeNodes:
# countNodes.py
#
# github_code/algorithms/python/DeleteNodeInABST:
# deleteNode.py
#
# github_code/algorithms/python/DiameterOfBinaryTree:
# diameterOfBinaryTree.py
#
# github_code/algorithms/python/DifferentWaysToAddParentheses:
# diffWaysToCompute.py
#
# github_code/algorithms/python/FibonacciNumber:
# fib.py
#
# github_code/algorithms/python/FindDuplicateSubtrees:
# findDuplicateSubtrees.py
#
# github_code/algorithms/python/FindTheDuplicateNumber:
# findDuplicate.py
#
# github_code/algorithms/python/firstMissingPositive:
# firstMissingPositive.py
#
# github_code/algorithms/python/FlattenBinaryTreeToLinkedList:
# flatten.py
#
# github_code/algorithms/python/FlipBinaryTreeToMatchPreorderTraversal:
# flipMatchVoyage.py
#
# github_code/algorithms/python/FlipEquivalentBinaryTrees:
# flipEquiv.py
#
# github_code/algorithms/python/HappyNumber:
# isHappy.py
#
# github_code/algorithms/python/HouseRobber:
# rob.py
#
# github_code/algorithms/python/HouseRobberIII:
# rob.py
#
# github_code/algorithms/python/ImageSmoother:
# imageSmoother.py
#
# github_code/algorithms/python/InsertionSortList:
# insertionSortList.py
#
# github_code/algorithms/python/jumpGame:
# jumpGame.py
#
# github_code/algorithms/python/K-diffPairsInAnArray:
# findPairs.py
#
# github_code/algorithms/python/KthSmallestElementInABST:
# kthSmallest.py
#
# github_code/algorithms/python/LargestNumberAtLeastTwiceOfOthers:
# dominantIndex.py
#
# github_code/algorithms/python/LargestPerimeterTriangle:
# largestPerimeter.py
#
# github_code/algorithms/python/LinkedListCycleII:
# detectCycle.py
#
# github_code/algorithms/python/LongestConsecutiveSequence:
# LongestConsecutive.py
#
# github_code/algorithms/python/LongestContinuousIncreasingSubsequence:
# findLengthOfLCIS.py
#
# github_code/algorithms/python/LongestTurbulentSubarray:
# maxTurbulenceSize.py
#
# github_code/algorithms/python/LongestUnivaluePath:
# longestUnivaluePath.py
#
# github_code/algorithms/python/LowestCommonAncestorOfABinarySearchTree:
# lowestCommonAncestor.py
#
# github_code/algorithms/python/LowestCommonAncestorOfABinaryTree:
# lowestCommonAncestor.py
#
# github_code/algorithms/python/MaximizeDistanceToClosestPerson:
# maxDistToClosest.py
#
# github_code/algorithms/python/MaximumAverageSubarrayI:
# findMaxAverage.py
#
# github_code/algorithms/python/MaximumProductOfThreeNumbers:
# maximumProduct.py
#
# github_code/algorithms/python/MaximumWidthOfBinaryTree:
# widthOfBinaryTree.py
#
# github_code/algorithms/python/MiddleOfTheLinkedList:
# middleOfTheLinkedList.py
#
# github_code/algorithms/python/MinCostClimbingStairs:
# minCostClimbingStairs.py
#
# github_code/algorithms/python/Non-decreasingArray:
# checkPossibility.py
#
# github_code/algorithms/python/NumberOfIslands:
# numIslands.py
#
# github_code/algorithms/python/PancakeSorting:
# pancakeSort.py
#
# github_code/algorithms/python/PartitionList:
# partition.py
#
# github_code/algorithms/python/PathSumII:
# pathSum.py
#
# github_code/algorithms/python/PathSumIII:
# pathSum.py
#
# github_code/algorithms/python/PopulatingNextRightPointersInEachNode:
# connect.py
#
# github_code/algorithms/python/PopulatingNextRightPointersInEachNodeII:
# connect.py
#
# github_code/algorithms/python/PositionsOfLargeGroups:
# largeGroupPositions.py
#
# github_code/algorithms/python/PrintBinaryTree:
# printTree.py
#
# github_code/algorithms/python/RedundantConnection:
# findRedundantConnection.py
#
# github_code/algorithms/python/RemoveDuplicatesFromSortedListII:
# deleteDuplicates.py
#
# github_code/algorithms/python/RemoveNthNodeFromEndOfList:
# removeNthFromEnd.py
#
# github_code/algorithms/python/ReorderList:
# reorderList.py
#
# github_code/algorithms/python/RevealCardsInIncreasingOrder:
# deckRevealedIncreasing.py
#
# github_code/algorithms/python/ReverseLinkedListII:
# reverseBetween.py
#
# github_code/algorithms/python/SearchA2DMatrixII:
# searchMatrix.py
#
# github_code/algorithms/python/SecondMinimumNodeInABinaryTree:
# findSecondMinimumValue.py
#
# github_code/algorithms/python/SerializeAndDeserializeBST:
# serialize.py
#
# github_code/algorithms/python/ShortestUnsortedContinuousSubarray:
# findUnsortedSubarray.py
#
# github_code/algorithms/python/SingleNumberII:
# SingleNumberII.py
#
# github_code/algorithms/python/SortList:
# sortList.py
#
# github_code/algorithms/python/SquaresOfSortedArray:
# sortedSquares.py
#
# github_code/algorithms/python/Subsets:
# subsets.py
#
# github_code/algorithms/python/SubtreeOfAnotherTree:
# isSubtree.py
#
# github_code/algorithms/python/SumOfLeftLeaves:
# sumOfLeftLeaves.py
#
# github_code/algorithms/python/SumRootToLeafNumbers:
# sumNumbers.py
#
# github_code/algorithms/python/SwimInRisingWater:
# swim_in_rising_water.py
#
# github_code/algorithms/python/ThirdMaximumNumber:
# thirdMax.py
#
# github_code/algorithms/python/UniqueBinarySearchTrees:
# numTrees.py
#
# github_code/algorithms/python/UniqueBinarySearchTreesII:
# generateTrees.py
#
# github_code/algorithms/python/uniquePaths:
# uniquePathsIII.py
#
# github_code/algorithms/python/ValidateBinarySearchTree:
# isValidBST.py
#
# github_code/algorithms/python/ValidMountainArray:
# validMountainArray.py
#
# github_code/algorithms/python/XOfAKindInADeckOfCards:
# hasGroupsSizeX.py
#
# github_code/database:
# README.md
#
# github_code/scripts:
# lib  README.md
#
# github_code/scripts/lib:
#
# github_code/shell:
# README.md

# %%
# !find github_code -type f | wc -l
# Out:
# 192

# %%
# !du -sh github_code
# Out:
# 3.3M	github_code

# %%
# !find github_code -type f | sed -n 's/..*\.//p' | sort | uniq -c
# Out:
#     106 java
#       4 md
#      82 py

# %%
# !find github_code -type f -name "*.md" -delete

# %%
# !find github_code -type f | sed -n 's/..*\.//p' | sort | uniq -c
# Out:
#     106 java
#      82 py

# %%
import os

def clean_code_file(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()

    # Strip extra whitespaces and empty lines
    cleaned_lines = [line.rstrip() for line in lines if line.strip()]

    with open(file_path, "w", encoding="utf-8") as f:
        f.write("\n".join(cleaned_lines) + "\n")

# Apply to all Java & Python files
for root, _, files in os.walk("github_code"):
    for file in files:
        if file.endswith(".java") or file.endswith(".py"):
            clean_code_file(os.path.join(root, file))

print("Code formatting cleaned successfully!")
# Out:
# Code formatting cleaned successfully!

# %%
{"language": "python", "code": "def hello():\n    print('Hello World!')"}
{"language": "java", "code": "public class Hello { public static void main(String[] args) { System.out.println(\"Hello World\"); } }"}
# Out:
# {'language': 'java',
#  'code': 'public class Hello { public static void main(String[] args) { System.out.println("Hello World"); } }'}

# %%
import json

data = []
for root, _, files in os.walk("github_code"):
    for file in files:
        file_path = os.path.join(root, file)
        with open(file_path, "r", encoding="utf-8") as f:
            code_content = f.read()

        # Identify language based on file extension
        language = "python" if file.endswith(".py") else "java"

        # Append to dataset
        data.append({"language": language, "code": code_content})

# Save as JSONL file
with open("dataset.jsonl", "w", encoding="utf-8") as f:
    for entry in data:
        f.write(json.dumps(entry) + "\n")

print("Dataset saved as dataset.jsonl")
# Out:
# Dataset saved as dataset.jsonl

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

output_file = "dataset.jsonl"

# Load CodeLlama tokenizer
tokenizer = AutoTokenizer.from_pretrained("codellama/CodeLlama-7b-hf")

tokenizer.pad_token = tokenizer.eos_token

# Tokenize the dataset
def tokenize_function(examples):
    return tokenizer(examples["code"], truncation=True, padding="max_length", max_length=512)

# Apply tokenization
from datasets import load_dataset

dataset = load_dataset("json", data_files=output_file, split="train")
tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Save tokenized dataset
tokenized_dataset.save_to_disk("tokenized_code_data")
print("Tokenization complete. Dataset saved.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/188 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/188 [00:00<?, ? examples/s]
# Tokenization complete. Dataset saved.

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install transformers datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Collecting datasets
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.13)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 19.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 21.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.3.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
from huggingface_hub import list_models

models = list_models(author="MetaAI")
for model in models:
    print(model.modelId)

# %%
print(tokenized_dataset)
# Out:
# Dataset({
#     features: ['language', 'code', 'input_ids', 'attention_mask'],
#     num_rows: 188
# })

# %%
import torch
from torch.utils.data import Dataset

class CodeDataset(Dataset):
    def __init__(self, tokenized_data):
        self.tokenized_data = tokenized_data

    def __len__(self):
        return len(self.tokenized_data)

    def __getitem__(self, idx):
        item = self.tokenized_data[idx]
        return {
            "input_ids": torch.tensor(item["input_ids"]),
            "attention_mask": torch.tensor(item["attention_mask"]),
        }

# Convert tokenized dataset to PyTorch format
train_dataset = CodeDataset(tokenized_dataset)

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False  # Set to False because CodeLlama does autoregressive learning, not masked learning
)

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("codellama/CodeLlama-7b-hf")

# Load model and force it onto GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = AutoModelForCausalLM.from_pretrained("codellama/CodeLlama-7b-hf").to(device)

print("Model loaded on:", next(model.parameters()).device)  # Should print: cuda:0
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
print(next(model.parameters()).device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-440199e2c02e> in <cell line: 0>()
# ----> 1 print(next(model.parameters()).device)
#
# NameError: name 'model' is not defined
